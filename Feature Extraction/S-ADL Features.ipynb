# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

folder_directory = '/content/drive/My Drive/Lab/'

# %%
import pandas as pd 
from pandas import Series, DataFrame
import numpy as np

phone_register = pd.read_csv('/content/drive/My Drive/Lab/phone_register.csv')
phone_receive = pd.read_csv('/content/drive/My Drive/Lab/phone_receive.csv')
sms_reply = pd.read_csv('/content/drive/My Drive/Lab/sms_reply.csv')
camera = pd.read_csv('/content/drive/My Drive/Lab/camera.csv')
transfer = pd.read_csv('/content/drive/My Drive/Lab/transfer.csv')
weather_searching = pd.read_csv('/content/drive/My Drive/Lab/weather_searching.csv')
weather_switching = pd.read_csv('/content/drive/My Drive/Lab/weather_switching.csv')
location_searching = pd.read_csv('/content/drive/My Drive/Lab/location_searching.csv')
location_switching = pd.read_csv('/content/drive/My Drive/Lab/location_switching.csv')
phone_register_E = pd.read_csv('/content/drive/My Drive/Lab/phone_register_E.csv')
camera_E = pd.read_csv('/content/drive/My Drive/Lab/camera_E.csv')

print(phone_register)
# Out:
#      Unnamed: 0        Trial 1  ...        Trial 8        Trial 9
# 0             1  1629608683436  ...  1629623021059  1629623493457
# 1             2  1629608685464  ...  1629623022550  1629623495500
# 2             3  1629608690331  ...  1629623030837  1629623499799
# 3             4  1629608695857  ...  1629623035687  1629623504917
# 4             5  1629608698832  ...  1629623038412  1629623506967
# ..          ...            ...  ...            ...            ...
# 301         302  1633839053310  ...  1633851730114  1633852378444
# 302         303  1633839056891  ...  1633851734191  1633852381527
# 303         304  1633839058051  ...  1633851736720  1633852383392
# 304         305  1633839058350  ...  1633851737032  1633852383756
# 305         306  1633839068704  ...  1633851752294  1633852398018
#
# [306 rows x 10 columns]

# %%
def feature_df(filename):
  df = pd.DataFrame(filename)
  df = df.apply(pd.to_numeric, errors='coerce')
  df = df.drop(columns=['Unnamed: 0'])
  num_df = np.array(df)
  return num_df

# %%
def calculate(filename, row, n):
  output_data = np.empty((0, 9))
  num_df = feature_df(filename)
  index = 0
  while (index < row * n):
    for i in range(index, index + n):
      b = i + 1
      for j in range(b, index + n):
        result = np.subtract(num_df[j], num_df[i])
        #print(result)
        #print(result.shape, output_data.shape)
        output_data = np.append(output_data, result[None, :], axis=0)
    index = index + n

  output_df = pd.DataFrame(output_data)
  output_df = output_df / 1000
  output_df.columns = ['Trial 1', 'Trial 2', 'Trial 3', 'Trial 4', 'Trial 5', 'Trial 6', 'Trial 7', 'Trial 8', 'Trial 9'] 



  # if (col == 40):
  #   output_df.columns = ['P013', 'P014', 'P015', 'P016', 'P017', 'P018', 'P019', 'P020', 'P021', 'P022', 'P023', 'P024', 'P025', 'P026', 'P027', 'P028', 'P029', 'P030', 'P031', 'P035', 'P032', 'P033', 'P034', 'P036', 'P037', 'P038', 'P039', 'P040', 'P041', 'P042', 'P044', 'P046', 'P048', 'P049', 'P043', 'P045', 'P047', 'P050', 'P052', 'P054']
  # elif (col == 34):
  #   output_df.columns = ['P013', 'P014', 'P015', 'P016', 'P017', 'P018', 'P019', 'P020', 'P021', 'P022', 'P023', 'P024', 'P025', 'P026', 'P027', 'P028', 'P029', 'P030', 'P031', 'P035', 'P032', 'P033', 'P034', 'P036', 'P037', 'P038', 'P039', 'P040', 'P041', 'P042', 'P044', 'P046', 'P048', 'P049']
  # elif (col == 6):
  #   output_df.columns= ['P043', 'P045', 'P047', 'P050', 'P052', 'P054']
  # elif (col == 31):
  #   output_df.columns = ['P022', 'P023', 'P024', 'P025', 'P026', 'P027', 'P028', 'P029', 'P030', 'P031', 'P035', 'P032', 'P033', 'P034', 'P036', 'P037', 'P038', 'P039', 'P040', 'P041', 'P042', 'P044', 'P046', 'P048', 'P049', 'P043', 'P045', 'P047', 'P050', 'P052', 'P054']
  # elif (col == 11):
  #   output_df.columns = ['P013', 'P014', 'P015', 'P016', 'P017', 'P018', 'P019', 'P020', 'P021', 'P023', 'P048']
  return output_df



# llist1 = np.array([1, 23, 45, 67, 89, 111, 133, 155, 177])
# llist2 = np.array([1, 11, 21, 31, 41, 51, 61, 71, 81])
# llist3 = np.array([1, 17, 33, 49, 65, 81, 97, 113, 129])
# llist4 = np.array([1, 25, 49, 73, 97, 121, 145, 169, 193])
# llist5 = np.array([1, 51, 101, 151, 201, 251, 301, 351, 401])
# llist6 = np.array([1, 25, 49, 73, 97, 121, 145, 169, 193])
# llist7 = np.array([1, 58, 115, 172, 229, 286, 343, 400, 457])
# llist8 = np.array([1, 31, 61, 91, 121, 151, 181, 211, 241])
# llist9 = np.array([1, 64, 127, 190, 253, 316, 379, 442, 505])
# llist10 = np.array([1, 27, 53, 79, 105, 131, 157, 183, 209])
# llist11 = np.array([1, 27, 53, 79, 105, 131, 157, 183, 209])

# %%
phone_register = calculate(phone_register, 34, 9)
phone_receive = calculate(phone_receive, 40, 7)
sms_reply = calculate(sms_reply, 40, 4)
camera = calculate(camera, 34, 6)
transfer = calculate(transfer, 40, 9)
weather_searching = calculate(weather_searching, 31, 8)
weather_switching = calculate(weather_switching, 31, 14)
location_searching = calculate(location_searching, 11, 9)
location_switching = calculate(location_switching, 11, 14)
phone_register_E = calculate(phone_register_E, 6, 11)
camera_E = calculate(camera_E, 6, 6)

print(phone_register)

############# P018 - trial 1 카메라 나옴1에 관련된 통계치 추가해야 함  ####################3
# Out:
#       Trial 1  Trial 2  Trial 3  Trial 4  ...  Trial 6  Trial 7  Trial 8  Trial 9
# 0       2.028    2.499    2.239    2.080  ...    1.813    1.860    1.491    2.043
# 1       6.895   15.685    6.324   10.221  ...    6.027    5.066    9.778    6.342
# 2      12.421   17.910   10.766   16.434  ...   11.257    9.591   14.628   11.460
# 3      15.396   21.847   13.121   19.202  ...   14.291   12.511   17.353   13.510
# 4      18.896   27.281   19.783   22.586  ...   17.858   16.915   21.810   17.800
# ...       ...      ...      ...      ...  ...      ...      ...      ...      ...
# 1219    1.459    1.808    1.123    2.290  ...    1.949    2.144    2.841    2.229
# 1220   11.813   13.572   12.917   15.560  ...   15.047   18.314   18.103   16.491
# 1221    0.299    0.302    0.305    0.420  ...    0.263    0.459    0.312    0.364
# 1222   10.653   12.066   12.099   13.690  ...   13.361   16.629   15.574   14.626
# ...

# %% [markdown]
# phone register:

# %% [markdown]
# # Phone Register

# %%
phone_register.insert(0,'Label',['screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2- 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감4 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2- screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감4 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2- screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감4 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2- 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 들어감2- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감4 - 연락처앱 들어감', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감4 - 문자앱 들어감2', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감4 - 전화앱 들어감(telecom)', '문자앱 들어감4 - 통화앱 들어감(incallui)'])

# %% [markdown]
# # Phone Receive

# %%
phone_receive.insert(0, 'Label', ['문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑','문자앱 들어감 - 문자도착', '전화 옴 - 문자도착', '알람-통화옴 - 문자도착', '알람-통화거절 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '전화 옴 - 문자앱 들어감', '알람-통화옴 - 문자앱 들어감', '알람-통화거절 - 문자앱 들어감', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '알람-통화옴 - 전화 옴', '알람-통화거절 - 전화 옴', '마지막 타이핑 - 전화 옴', '문자앱 나옴 - 전화 옴', '알람-통화거절 - 알람-통화옴', '마지막 타이핑 - 알람-통화옴', '문자앱 나옴 - 알람-통화옴', '마지막 타이핑 - 알람-통화거절', '문자앱 나옴 - 알람-통화거절', '문자앱 나옴 - 마지막 타이핑'])

# %% [markdown]
# # SMS Reply

# %%
sms_reply.insert(0, 'Label', ['문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑', '문자앱 들어감 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴 - 문자도착', '마지막 타이핑 - 문자앱 들어감', '문자앱 나옴 - 문자앱 들어감', '문자앱 나옴 - 마지막 타이핑'])

# %% [markdown]
# # Camera

# %%
camera.insert(0, 'Label', ['문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감'])

# %% [markdown]
# # Transfer

# %%
transfer.insert(0, 'Label', ['문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '송금앱 들어감1 - 문자도착', '송금앱 나옴10 - 문자도착', '문자앱 들어감3 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 들어감4 - 문자도착', '문자앱 나옴4 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 들어감1', '송금앱 나옴10 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '문자앱 나옴4 - 문자앱 들어감1', '송금앱 들어감1 - 문자앱 나옴1', '송금앱 나옴10 - 문자앱 나옴1', '문자앱 들어감3 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 들어감4 - 문자앱 나옴1', '문자앱 나옴4 - 문자앱 나옴1', '송금앱 나옴10 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 들어감1', '마지막 타이핑 - 송금앱 들어감1', '문자앱 들어감4 - 송금앱 들어감1', '문자앱 나옴4 - 송금앱 들어감1', '문자앱 들어감3 - 송금앱 나옴10', '마지막 타이핑 - 송금앱 나옴10', '문자앱 들어감4 - 송금앱 나옴10', '문자앱 나옴4 - 송금앱 나옴10', '마지막 타이핑 - 문자앱 들어감3', '문자앱 들어감4 - 문자앱 들어감3', '문자앱 나옴4 - 문자앱 들어감3', '문자앱 들어감4 - 마지막 타이핑', '문자앱 나옴4 - 마지막 타이핑', '문자앱 나옴4 - 문자앱 들어감4'])

# %% [markdown]
# # Weather Searching

# %%
weather_searching.insert(0, 'Label', ['문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b15e9319ab03> in <module>
# ----> 1 weather_searching.insert(0, 'Label', ['문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착', '문자앱 들어감2 - 문자도착', '마지막 타이핑 - 문자도착', '문자앱 나옴2 - 문자도착', '문자앱 나옴1 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 들어감1', '크롬앱 나옴 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '마지막 타이핑 - 문자앱 들어감1', '문자앱 나옴2 - 문자앱 들어감1', '크롬앱 들어감 - 문자앱 나옴1', '크롬앱 나옴 - 문자앱 나옴1', '문자앱 들어감2 - 문자앱 나옴1', '마지막 타이핑 - 문자앱 나옴1', '문자앱 나옴2 - 문자앱 나옴1', '크롬앱 나옴 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 들어감', '마지막 타이핑 - 크롬앱 들어감', '문자앱 나옴2 - 크롬앱 들어감', '문자앱 들어감2 - 크롬앱 나옴', '마지막 타이핑 - 크롬앱 나옴', '문자앱 나옴2 - 크롬앱 나옴', '마지막 타이핑 - 문자앱 들어감2', '문자앱 나옴2 - 문자앱 들어감2', '문자앱 나옴2 - 마지막 타이핑', '문자앱 들어감1 - 문자도착', '문자앱 나옴1 - 문자도착', '크롬앱 들어감 - 문자도착', '크롬앱 나옴 - 문자도착'...
#
# NameError: name 'weather_searching' is not defined

# %% [markdown]
# # Weather Switching

# %%
weather_switching.insert(0, 'Label', ['문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '크롬앱 들어감1 – 문자도착1', '마지막 타이핑(크롬앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감(incallui) – 문자도착1', '크롬앱 들어감2 – 문자도착1', '문자도착2 – 문자도착1', '마지막 타이핑(크롬앱)2 – 문자도착1', '크롬앱 나옴2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '문자앱 나옴2 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(크롬앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감(incallui) – 문자앱 들어감1', '크롬앱 들어감2 – 문자앱 들어감1', '문자도착2 – 문자앱 들어감1', '마지막 타이핑(크롬앱)2 – 문자앱 들어감1', '크롬앱 나옴2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '문자앱 나옴2 – 문자앱 들어감1', '크롬앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감(incallui) – 문자앱 나옴1', '크롬앱 들어감2 – 문자앱 나옴1', '문자도착2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)2 – 문자앱 나옴1', '크롬앱 나옴2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '문자앱 나옴2 – 문자앱 나옴1', '마지막 타이핑(크롬앱)1 – 크롬앱 들어감1', '전화 옴 – 크롬앱 들어감1', '통화앱 들어감(incallui) – 크롬앱 들어감1', '크롬앱 들어감2 – 크롬앱 들어감1', '문자도착2 – 크롬앱 들어감1', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감1', '크롬앱 나옴2 – 크롬앱 들어감1', '문자앱 들어감2 – 크롬앱 들어감1', '마지막 타이핑(문자앱) – 크롬앱 들어감1', '문자앱 나옴2 – 크롬앱 들어감1', '전화 옴 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 마지막 타이핑(크롬앱)1', '크롬앱 들어감2 – 마지막 타이핑(크롬앱)1', '문자도착2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(크롬앱)2 – 마지막 타이핑(크롬앱)1', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)1', '문자앱 들어감2 – 마지막 타이핑(크롬앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)1', '문자앱 나옴2 – 마지막 타이핑(크롬앱)1', '통화앱 들어감(incallui) – 전화 옴', '크롬앱 들어감2 – 전화 옴', '문자도착2 – 전화 옴', '마지막 타이핑(크롬앱)2 – 전화 옴', '크롬앱 나옴2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '문자앱 나옴2 – 전화 옴', '크롬앱 들어감2 – 통화앱 들어감(incallui)', '문자도착2 – 통화앱 들어감(incallui)', '마지막 타이핑(크롬앱)2 – 통화앱 들어감(incallui)', '크롬앱 나옴2 – 통화앱 들어감(incallui)', '문자앱 들어감2 – 통화앱 들어감(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감(incallui)', '문자앱 나옴2 – 통화앱 들어감(incallui)', '문자도착2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 크롬앱 들어감2', '크롬앱 나옴2 – 크롬앱 들어감2', '문자앱 들어감2 – 크롬앱 들어감2', '마지막 타이핑(문자앱) – 크롬앱 들어감2', '문자앱 나옴2 – 크롬앱 들어감2', '마지막 타이핑(크롬앱)2 – 문자도착2', '크롬앱 나옴2 – 문자도착2', '문자앱 들어감2 – 문자도착2', '마지막 타이핑(문자앱) – 문자도착2', '문자앱 나옴2 – 문자도착2', '크롬앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 마지막 타이핑(크롬앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(크롬앱)2', '문자앱 나옴2 – 마지막 타이핑(크롬앱)2', '문자앱 들어감2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 크롬앱 나옴2', '문자앱 나옴2 – 크롬앱 나옴2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '문자앱 나옴2 – 문자앱 들어2', '문자앱 나옴2 – 마지막 타이핑(문자앱)'])

# %% [markdown]
# # Location Searching

# %%
location_searching.insert(0, 'Label', ['문자앱 들어감1 – 문자도착', '문자앱 나옴1 – 문자도착', '지도앱 들어감1 – 문자도착', '마지막 타이핑(지도앱) – 문자도착', '지도앱 나옴1 – 문자도착', '문자앱 들어감4 – 문자도착', '마지막 타이핑(문자앱) – 문자도착', '지도앱 들어감2 – 문자도착', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱) – 문자앱 들어감1', '지도앱 나옴1 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 문자앱 나옴1', '지도앱 나옴1 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 지도앱 들어감1', '지도앱 나옴1 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '지도앱 나옴1 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 마지막 타이핑(지도앱)', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)', '지도앱 들어감2 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 지도앱 나옴1', '지도앱 들어감2 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감2 – 문자앱 들어감4', '지도앱 들어감2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착', '문자앱 나옴1 – 문자도착', '지도앱 들어감1 – 문자도착', '마지막 타이핑(지도앱) – 문자도착', '지도앱 나옴1 – 문자도착', '문자앱 들어감4 – 문자도착', '마지막 타이핑(문자앱) – 문자도착', '지도앱 들어감2 – 문자도착', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱) – 문자앱 들어감1', '지도앱 나옴1 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 문자앱 나옴1', '지도앱 나옴1 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 지도앱 들어감1', '지도앱 나옴1 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '지도앱 나옴1 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 마지막 타이핑(지도앱)', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)', '지도앱 들어감2 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 지도앱 나옴1', '지도앱 들어감2 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감2 – 문자앱 들어감4', '지도앱 들어감2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착', '문자앱 나옴1 – 문자도착', '지도앱 들어감1 – 문자도착', '마지막 타이핑(지도앱) – 문자도착', '지도앱 나옴1 – 문자도착', '문자앱 들어감4 – 문자도착', '마지막 타이핑(문자앱) – 문자도착', '지도앱 들어감2 – 문자도착', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱) – 문자앱 들어감1', '지도앱 나옴1 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 문자앱 나옴1', '지도앱 나옴1 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 지도앱 들어감1', '지도앱 나옴1 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '지도앱 나옴1 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 마지막 타이핑(지도앱)', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)', '지도앱 들어감2 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 지도앱 나옴1', '지도앱 들어감2 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감2 – 문자앱 들어감4', '지도앱 들어감2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착', '문자앱 나옴1 – 문자도착', '지도앱 들어감1 – 문자도착', '마지막 타이핑(지도앱) – 문자도착', '지도앱 나옴1 – 문자도착', '문자앱 들어감4 – 문자도착', '마지막 타이핑(문자앱) – 문자도착', '지도앱 들어감2 – 문자도착', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱) – 문자앱 들어감1', '지도앱 나옴1 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 문자앱 나옴1', '지도앱 나옴1 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 지도앱 들어감1', '지도앱 나옴1 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '지도앱 나옴1 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 마지막 타이핑(지도앱)', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)', '지도앱 들어감2 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 지도앱 나옴1', '지도앱 들어감2 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감2 – 문자앱 들어감4', '지도앱 들어감2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착', '문자앱 나옴1 – 문자도착', '지도앱 들어감1 – 문자도착', '마지막 타이핑(지도앱) – 문자도착', '지도앱 나옴1 – 문자도착', '문자앱 들어감4 – 문자도착', '마지막 타이핑(문자앱) – 문자도착', '지도앱 들어감2 – 문자도착', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱) – 문자앱 들어감1', '지도앱 나옴1 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 문자앱 나옴1', '지도앱 나옴1 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 지도앱 들어감1', '지도앱 나옴1 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '지도앱 나옴1 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 마지막 타이핑(지도앱)', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)', '지도앱 들어감2 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 지도앱 나옴1', '지도앱 들어감2 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감2 – 문자앱 들어감4', '지도앱 들어감2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착', '문자앱 나옴1 – 문자도착', '지도앱 들어감1 – 문자도착', '마지막 타이핑(지도앱) – 문자도착', '지도앱 나옴1 – 문자도착', '문자앱 들어감4 – 문자도착', '마지막 타이핑(문자앱) – 문자도착', '지도앱 들어감2 – 문자도착', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱) – 문자앱 들어감1', '지도앱 나옴1 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 문자앱 나옴1', '지도앱 나옴1 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 지도앱 들어감1', '지도앱 나옴1 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '지도앱 나옴1 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 마지막 타이핑(지도앱)', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)', '지도앱 들어감2 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 지도앱 나옴1', '지도앱 들어감2 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감2 – 문자앱 들어감4', '지도앱 들어감2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착', '문자앱 나옴1 – 문자도착', '지도앱 들어감1 – 문자도착', '마지막 타이핑(지도앱) – 문자도착', '지도앱 나옴1 – 문자도착', '문자앱 들어감4 – 문자도착', '마지막 타이핑(문자앱) – 문자도착', '지도앱 들어감2 – 문자도착', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱) – 문자앱 들어감1', '지도앱 나옴1 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 문자앱 나옴1', '지도앱 나옴1 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 지도앱 들어감1', '지도앱 나옴1 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '지도앱 나옴1 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 마지막 타이핑(지도앱)', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)', '지도앱 들어감2 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 지도앱 나옴1', '지도앱 들어감2 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감2 – 문자앱 들어감4', '지도앱 들어감2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착', '문자앱 나옴1 – 문자도착', '지도앱 들어감1 – 문자도착', '마지막 타이핑(지도앱) – 문자도착', '지도앱 나옴1 – 문자도착', '문자앱 들어감4 – 문자도착', '마지막 타이핑(문자앱) – 문자도착', '지도앱 들어감2 – 문자도착', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱) – 문자앱 들어감1', '지도앱 나옴1 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 문자앱 나옴1', '지도앱 나옴1 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 지도앱 들어감1', '지도앱 나옴1 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '지도앱 나옴1 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 마지막 타이핑(지도앱)', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)', '지도앱 들어감2 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 지도앱 나옴1', '지도앱 들어감2 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감2 – 문자앱 들어감4', '지도앱 들어감2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착', '문자앱 나옴1 – 문자도착', '지도앱 들어감1 – 문자도착', '마지막 타이핑(지도앱) – 문자도착', '지도앱 나옴1 – 문자도착', '문자앱 들어감4 – 문자도착', '마지막 타이핑(문자앱) – 문자도착', '지도앱 들어감2 – 문자도착', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱) – 문자앱 들어감1', '지도앱 나옴1 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 문자앱 나옴1', '지도앱 나옴1 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 지도앱 들어감1', '지도앱 나옴1 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '지도앱 나옴1 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 마지막 타이핑(지도앱)', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)', '지도앱 들어감2 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 지도앱 나옴1', '지도앱 들어감2 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감2 – 문자앱 들어감4', '지도앱 들어감2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착', '문자앱 나옴1 – 문자도착', '지도앱 들어감1 – 문자도착', '마지막 타이핑(지도앱) – 문자도착', '지도앱 나옴1 – 문자도착', '문자앱 들어감4 – 문자도착', '마지막 타이핑(문자앱) – 문자도착', '지도앱 들어감2 – 문자도착', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱) – 문자앱 들어감1', '지도앱 나옴1 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 문자앱 나옴1', '지도앱 나옴1 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 지도앱 들어감1', '지도앱 나옴1 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '지도앱 나옴1 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 마지막 타이핑(지도앱)', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)', '지도앱 들어감2 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 지도앱 나옴1', '지도앱 들어감2 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감2 – 문자앱 들어감4', '지도앱 들어감2 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착', '문자앱 나옴1 – 문자도착', '지도앱 들어감1 – 문자도착', '마지막 타이핑(지도앱) – 문자도착', '지도앱 나옴1 – 문자도착', '문자앱 들어감4 – 문자도착', '마지막 타이핑(문자앱) – 문자도착', '지도앱 들어감2 – 문자도착', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱) – 문자앱 들어감1', '지도앱 나옴1 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 문자앱 나옴1', '지도앱 나옴1 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱) – 지도앱 들어감1', '지도앱 나옴1 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '지도앱 나옴1 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 마지막 타이핑(지도앱)', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)', '지도앱 들어감2 – 마지막 타이핑(지도앱)', '문자앱 들어감4 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 지도앱 나옴1', '지도앱 들어감2 – 지도앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감2 – 문자앱 들어감4', '지도앱 들어감2 – 마지막 타이핑(문자앱)'])

# %% [markdown]
# # Location Switching

# %%
location_switching.insert(0, 'Label', ['문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '지도앱 들어감1 – 문자도착1', '마지막 타이핑(지도앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감1(incallui) – 문자도착1', '지도앱 들어감2 – 문자도착1', '마지막 타이핑(지도앱)2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '문자앱 들어감3 – 문자도착1', '문자앱 들어감4 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '지도앱 들어감3 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감1(incallui) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(지도앱)2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '문자앱 들어감3 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감3 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감1(incallui) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱)2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '문자앱 들어감3 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감3 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 지도앱 들어감1', '전화 옴 – 지도앱 들어감1', '통화앱 들어감1(incallui) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '마지막 타이핑(지도앱)2 – 지도앱 들어감1', '문자앱 들어감2 – 지도앱 들어감1', '문자앱 들어감3 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감3 – 지도앱 들어감1', '전화 옴 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 마지막 타이핑(지도앱)1', '지도앱 들어감2 – 마지막 타이핑(지도앱)1', '마지막 타이핑(지도앱)2 – 마지막 타이핑(지도앱)1', '문자앱 들어감2 – 마지막 타이핑(지도앱)1', '문자앱 들어감3 – 마지막 타이핑(지도앱)1', '문자앱 들어감4 – 마지막 타이핑(지도앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)1', '지도앱 들어감3 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 전화 옴', '지도앱 들어감2 – 전화 옴', '마지막 타이핑(지도앱)2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '문자앱 들어감3 – 전화 옴', '문자앱 들어감4 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '지도앱 들어감3 – 전화 옴', '지도앱 들어감2 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 통화앱 들어감1(incallui)', '문자앱 들어감2 – 통화앱 들어감1(incallui)', '문자앱 들어감3 – 통화앱 들어감1(incallui)', '문자앱 들어감4 – 통화앱 들어감1(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감1(incallui)', '지도앱 들어감3 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 지도앱 들어감2', '문자앱 들어감2 – 지도앱 들어감2', '문자앱 들어감3 – 지도앱 들어감2', '문자앱 들어감4 – 지도앱 들어감2', '마지막 타이핑(문자앱) – 지도앱 들어감2', '지도앱 들어감3 – 지도앱 들어감2', '문자앱 들어감2 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감4 – 마지막 타이핑(지도앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)2', '지도앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '지도앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감3', '지도앱 들어감3 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감3 – 문자앱 들어감4', '지도앱 들어감3 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '지도앱 들어감1 – 문자도착1', '마지막 타이핑(지도앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감1(incallui) – 문자도착1', '지도앱 들어감2 – 문자도착1', '마지막 타이핑(지도앱)2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '문자앱 들어감3 – 문자도착1', '문자앱 들어감4 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '지도앱 들어감3 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감1(incallui) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(지도앱)2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '문자앱 들어감3 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감3 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감1(incallui) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱)2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '문자앱 들어감3 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감3 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 지도앱 들어감1', '전화 옴 – 지도앱 들어감1', '통화앱 들어감1(incallui) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '마지막 타이핑(지도앱)2 – 지도앱 들어감1', '문자앱 들어감2 – 지도앱 들어감1', '문자앱 들어감3 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감3 – 지도앱 들어감1', '전화 옴 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 마지막 타이핑(지도앱)1', '지도앱 들어감2 – 마지막 타이핑(지도앱)1', '마지막 타이핑(지도앱)2 – 마지막 타이핑(지도앱)1', '문자앱 들어감2 – 마지막 타이핑(지도앱)1', '문자앱 들어감3 – 마지막 타이핑(지도앱)1', '문자앱 들어감4 – 마지막 타이핑(지도앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)1', '지도앱 들어감3 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 전화 옴', '지도앱 들어감2 – 전화 옴', '마지막 타이핑(지도앱)2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '문자앱 들어감3 – 전화 옴', '문자앱 들어감4 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '지도앱 들어감3 – 전화 옴', '지도앱 들어감2 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 통화앱 들어감1(incallui)', '문자앱 들어감2 – 통화앱 들어감1(incallui)', '문자앱 들어감3 – 통화앱 들어감1(incallui)', '문자앱 들어감4 – 통화앱 들어감1(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감1(incallui)', '지도앱 들어감3 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 지도앱 들어감2', '문자앱 들어감2 – 지도앱 들어감2', '문자앱 들어감3 – 지도앱 들어감2', '문자앱 들어감4 – 지도앱 들어감2', '마지막 타이핑(문자앱) – 지도앱 들어감2', '지도앱 들어감3 – 지도앱 들어감2', '문자앱 들어감2 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감4 – 마지막 타이핑(지도앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)2', '지도앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '지도앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감3', '지도앱 들어감3 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감3 – 문자앱 들어감4', '지도앱 들어감3 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '지도앱 들어감1 – 문자도착1', '마지막 타이핑(지도앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감1(incallui) – 문자도착1', '지도앱 들어감2 – 문자도착1', '마지막 타이핑(지도앱)2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '문자앱 들어감3 – 문자도착1', '문자앱 들어감4 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '지도앱 들어감3 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감1(incallui) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(지도앱)2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '문자앱 들어감3 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감3 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감1(incallui) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱)2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '문자앱 들어감3 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감3 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 지도앱 들어감1', '전화 옴 – 지도앱 들어감1', '통화앱 들어감1(incallui) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '마지막 타이핑(지도앱)2 – 지도앱 들어감1', '문자앱 들어감2 – 지도앱 들어감1', '문자앱 들어감3 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감3 – 지도앱 들어감1', '전화 옴 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 마지막 타이핑(지도앱)1', '지도앱 들어감2 – 마지막 타이핑(지도앱)1', '마지막 타이핑(지도앱)2 – 마지막 타이핑(지도앱)1', '문자앱 들어감2 – 마지막 타이핑(지도앱)1', '문자앱 들어감3 – 마지막 타이핑(지도앱)1', '문자앱 들어감4 – 마지막 타이핑(지도앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)1', '지도앱 들어감3 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 전화 옴', '지도앱 들어감2 – 전화 옴', '마지막 타이핑(지도앱)2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '문자앱 들어감3 – 전화 옴', '문자앱 들어감4 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '지도앱 들어감3 – 전화 옴', '지도앱 들어감2 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 통화앱 들어감1(incallui)', '문자앱 들어감2 – 통화앱 들어감1(incallui)', '문자앱 들어감3 – 통화앱 들어감1(incallui)', '문자앱 들어감4 – 통화앱 들어감1(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감1(incallui)', '지도앱 들어감3 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 지도앱 들어감2', '문자앱 들어감2 – 지도앱 들어감2', '문자앱 들어감3 – 지도앱 들어감2', '문자앱 들어감4 – 지도앱 들어감2', '마지막 타이핑(문자앱) – 지도앱 들어감2', '지도앱 들어감3 – 지도앱 들어감2', '문자앱 들어감2 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감4 – 마지막 타이핑(지도앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)2', '지도앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '지도앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감3', '지도앱 들어감3 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감3 – 문자앱 들어감4', '지도앱 들어감3 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '지도앱 들어감1 – 문자도착1', '마지막 타이핑(지도앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감1(incallui) – 문자도착1', '지도앱 들어감2 – 문자도착1', '마지막 타이핑(지도앱)2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '문자앱 들어감3 – 문자도착1', '문자앱 들어감4 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '지도앱 들어감3 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감1(incallui) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(지도앱)2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '문자앱 들어감3 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감3 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감1(incallui) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱)2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '문자앱 들어감3 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감3 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 지도앱 들어감1', '전화 옴 – 지도앱 들어감1', '통화앱 들어감1(incallui) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '마지막 타이핑(지도앱)2 – 지도앱 들어감1', '문자앱 들어감2 – 지도앱 들어감1', '문자앱 들어감3 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감3 – 지도앱 들어감1', '전화 옴 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 마지막 타이핑(지도앱)1', '지도앱 들어감2 – 마지막 타이핑(지도앱)1', '마지막 타이핑(지도앱)2 – 마지막 타이핑(지도앱)1', '문자앱 들어감2 – 마지막 타이핑(지도앱)1', '문자앱 들어감3 – 마지막 타이핑(지도앱)1', '문자앱 들어감4 – 마지막 타이핑(지도앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)1', '지도앱 들어감3 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 전화 옴', '지도앱 들어감2 – 전화 옴', '마지막 타이핑(지도앱)2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '문자앱 들어감3 – 전화 옴', '문자앱 들어감4 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '지도앱 들어감3 – 전화 옴', '지도앱 들어감2 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 통화앱 들어감1(incallui)', '문자앱 들어감2 – 통화앱 들어감1(incallui)', '문자앱 들어감3 – 통화앱 들어감1(incallui)', '문자앱 들어감4 – 통화앱 들어감1(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감1(incallui)', '지도앱 들어감3 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 지도앱 들어감2', '문자앱 들어감2 – 지도앱 들어감2', '문자앱 들어감3 – 지도앱 들어감2', '문자앱 들어감4 – 지도앱 들어감2', '마지막 타이핑(문자앱) – 지도앱 들어감2', '지도앱 들어감3 – 지도앱 들어감2', '문자앱 들어감2 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감4 – 마지막 타이핑(지도앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)2', '지도앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '지도앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감3', '지도앱 들어감3 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감3 – 문자앱 들어감4', '지도앱 들어감3 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '지도앱 들어감1 – 문자도착1', '마지막 타이핑(지도앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감1(incallui) – 문자도착1', '지도앱 들어감2 – 문자도착1', '마지막 타이핑(지도앱)2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '문자앱 들어감3 – 문자도착1', '문자앱 들어감4 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '지도앱 들어감3 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감1(incallui) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(지도앱)2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '문자앱 들어감3 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감3 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감1(incallui) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱)2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '문자앱 들어감3 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감3 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 지도앱 들어감1', '전화 옴 – 지도앱 들어감1', '통화앱 들어감1(incallui) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '마지막 타이핑(지도앱)2 – 지도앱 들어감1', '문자앱 들어감2 – 지도앱 들어감1', '문자앱 들어감3 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감3 – 지도앱 들어감1', '전화 옴 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 마지막 타이핑(지도앱)1', '지도앱 들어감2 – 마지막 타이핑(지도앱)1', '마지막 타이핑(지도앱)2 – 마지막 타이핑(지도앱)1', '문자앱 들어감2 – 마지막 타이핑(지도앱)1', '문자앱 들어감3 – 마지막 타이핑(지도앱)1', '문자앱 들어감4 – 마지막 타이핑(지도앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)1', '지도앱 들어감3 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 전화 옴', '지도앱 들어감2 – 전화 옴', '마지막 타이핑(지도앱)2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '문자앱 들어감3 – 전화 옴', '문자앱 들어감4 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '지도앱 들어감3 – 전화 옴', '지도앱 들어감2 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 통화앱 들어감1(incallui)', '문자앱 들어감2 – 통화앱 들어감1(incallui)', '문자앱 들어감3 – 통화앱 들어감1(incallui)', '문자앱 들어감4 – 통화앱 들어감1(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감1(incallui)', '지도앱 들어감3 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 지도앱 들어감2', '문자앱 들어감2 – 지도앱 들어감2', '문자앱 들어감3 – 지도앱 들어감2', '문자앱 들어감4 – 지도앱 들어감2', '마지막 타이핑(문자앱) – 지도앱 들어감2', '지도앱 들어감3 – 지도앱 들어감2', '문자앱 들어감2 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감4 – 마지막 타이핑(지도앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)2', '지도앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '지도앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감3', '지도앱 들어감3 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감3 – 문자앱 들어감4', '지도앱 들어감3 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '지도앱 들어감1 – 문자도착1', '마지막 타이핑(지도앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감1(incallui) – 문자도착1', '지도앱 들어감2 – 문자도착1', '마지막 타이핑(지도앱)2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '문자앱 들어감3 – 문자도착1', '문자앱 들어감4 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '지도앱 들어감3 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감1(incallui) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(지도앱)2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '문자앱 들어감3 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감3 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감1(incallui) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱)2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '문자앱 들어감3 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감3 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 지도앱 들어감1', '전화 옴 – 지도앱 들어감1', '통화앱 들어감1(incallui) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '마지막 타이핑(지도앱)2 – 지도앱 들어감1', '문자앱 들어감2 – 지도앱 들어감1', '문자앱 들어감3 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감3 – 지도앱 들어감1', '전화 옴 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 마지막 타이핑(지도앱)1', '지도앱 들어감2 – 마지막 타이핑(지도앱)1', '마지막 타이핑(지도앱)2 – 마지막 타이핑(지도앱)1', '문자앱 들어감2 – 마지막 타이핑(지도앱)1', '문자앱 들어감3 – 마지막 타이핑(지도앱)1', '문자앱 들어감4 – 마지막 타이핑(지도앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)1', '지도앱 들어감3 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 전화 옴', '지도앱 들어감2 – 전화 옴', '마지막 타이핑(지도앱)2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '문자앱 들어감3 – 전화 옴', '문자앱 들어감4 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '지도앱 들어감3 – 전화 옴', '지도앱 들어감2 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 통화앱 들어감1(incallui)', '문자앱 들어감2 – 통화앱 들어감1(incallui)', '문자앱 들어감3 – 통화앱 들어감1(incallui)', '문자앱 들어감4 – 통화앱 들어감1(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감1(incallui)', '지도앱 들어감3 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 지도앱 들어감2', '문자앱 들어감2 – 지도앱 들어감2', '문자앱 들어감3 – 지도앱 들어감2', '문자앱 들어감4 – 지도앱 들어감2', '마지막 타이핑(문자앱) – 지도앱 들어감2', '지도앱 들어감3 – 지도앱 들어감2', '문자앱 들어감2 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감4 – 마지막 타이핑(지도앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)2', '지도앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '지도앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감3', '지도앱 들어감3 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감3 – 문자앱 들어감4', '지도앱 들어감3 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '지도앱 들어감1 – 문자도착1', '마지막 타이핑(지도앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감1(incallui) – 문자도착1', '지도앱 들어감2 – 문자도착1', '마지막 타이핑(지도앱)2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '문자앱 들어감3 – 문자도착1', '문자앱 들어감4 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '지도앱 들어감3 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감1(incallui) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(지도앱)2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '문자앱 들어감3 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감3 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감1(incallui) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱)2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '문자앱 들어감3 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감3 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 지도앱 들어감1', '전화 옴 – 지도앱 들어감1', '통화앱 들어감1(incallui) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '마지막 타이핑(지도앱)2 – 지도앱 들어감1', '문자앱 들어감2 – 지도앱 들어감1', '문자앱 들어감3 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감3 – 지도앱 들어감1', '전화 옴 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 마지막 타이핑(지도앱)1', '지도앱 들어감2 – 마지막 타이핑(지도앱)1', '마지막 타이핑(지도앱)2 – 마지막 타이핑(지도앱)1', '문자앱 들어감2 – 마지막 타이핑(지도앱)1', '문자앱 들어감3 – 마지막 타이핑(지도앱)1', '문자앱 들어감4 – 마지막 타이핑(지도앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)1', '지도앱 들어감3 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 전화 옴', '지도앱 들어감2 – 전화 옴', '마지막 타이핑(지도앱)2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '문자앱 들어감3 – 전화 옴', '문자앱 들어감4 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '지도앱 들어감3 – 전화 옴', '지도앱 들어감2 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 통화앱 들어감1(incallui)', '문자앱 들어감2 – 통화앱 들어감1(incallui)', '문자앱 들어감3 – 통화앱 들어감1(incallui)', '문자앱 들어감4 – 통화앱 들어감1(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감1(incallui)', '지도앱 들어감3 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 지도앱 들어감2', '문자앱 들어감2 – 지도앱 들어감2', '문자앱 들어감3 – 지도앱 들어감2', '문자앱 들어감4 – 지도앱 들어감2', '마지막 타이핑(문자앱) – 지도앱 들어감2', '지도앱 들어감3 – 지도앱 들어감2', '문자앱 들어감2 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감4 – 마지막 타이핑(지도앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)2', '지도앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '지도앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감3', '지도앱 들어감3 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감3 – 문자앱 들어감4', '지도앱 들어감3 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '지도앱 들어감1 – 문자도착1', '마지막 타이핑(지도앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감1(incallui) – 문자도착1', '지도앱 들어감2 – 문자도착1', '마지막 타이핑(지도앱)2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '문자앱 들어감3 – 문자도착1', '문자앱 들어감4 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '지도앱 들어감3 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감1(incallui) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(지도앱)2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '문자앱 들어감3 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감3 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감1(incallui) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱)2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '문자앱 들어감3 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감3 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 지도앱 들어감1', '전화 옴 – 지도앱 들어감1', '통화앱 들어감1(incallui) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '마지막 타이핑(지도앱)2 – 지도앱 들어감1', '문자앱 들어감2 – 지도앱 들어감1', '문자앱 들어감3 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감3 – 지도앱 들어감1', '전화 옴 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 마지막 타이핑(지도앱)1', '지도앱 들어감2 – 마지막 타이핑(지도앱)1', '마지막 타이핑(지도앱)2 – 마지막 타이핑(지도앱)1', '문자앱 들어감2 – 마지막 타이핑(지도앱)1', '문자앱 들어감3 – 마지막 타이핑(지도앱)1', '문자앱 들어감4 – 마지막 타이핑(지도앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)1', '지도앱 들어감3 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 전화 옴', '지도앱 들어감2 – 전화 옴', '마지막 타이핑(지도앱)2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '문자앱 들어감3 – 전화 옴', '문자앱 들어감4 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '지도앱 들어감3 – 전화 옴', '지도앱 들어감2 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 통화앱 들어감1(incallui)', '문자앱 들어감2 – 통화앱 들어감1(incallui)', '문자앱 들어감3 – 통화앱 들어감1(incallui)', '문자앱 들어감4 – 통화앱 들어감1(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감1(incallui)', '지도앱 들어감3 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 지도앱 들어감2', '문자앱 들어감2 – 지도앱 들어감2', '문자앱 들어감3 – 지도앱 들어감2', '문자앱 들어감4 – 지도앱 들어감2', '마지막 타이핑(문자앱) – 지도앱 들어감2', '지도앱 들어감3 – 지도앱 들어감2', '문자앱 들어감2 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감4 – 마지막 타이핑(지도앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)2', '지도앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '지도앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감3', '지도앱 들어감3 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감3 – 문자앱 들어감4', '지도앱 들어감3 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '지도앱 들어감1 – 문자도착1', '마지막 타이핑(지도앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감1(incallui) – 문자도착1', '지도앱 들어감2 – 문자도착1', '마지막 타이핑(지도앱)2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '문자앱 들어감3 – 문자도착1', '문자앱 들어감4 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '지도앱 들어감3 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감1(incallui) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(지도앱)2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '문자앱 들어감3 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감3 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감1(incallui) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱)2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '문자앱 들어감3 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감3 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 지도앱 들어감1', '전화 옴 – 지도앱 들어감1', '통화앱 들어감1(incallui) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '마지막 타이핑(지도앱)2 – 지도앱 들어감1', '문자앱 들어감2 – 지도앱 들어감1', '문자앱 들어감3 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감3 – 지도앱 들어감1', '전화 옴 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 마지막 타이핑(지도앱)1', '지도앱 들어감2 – 마지막 타이핑(지도앱)1', '마지막 타이핑(지도앱)2 – 마지막 타이핑(지도앱)1', '문자앱 들어감2 – 마지막 타이핑(지도앱)1', '문자앱 들어감3 – 마지막 타이핑(지도앱)1', '문자앱 들어감4 – 마지막 타이핑(지도앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)1', '지도앱 들어감3 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 전화 옴', '지도앱 들어감2 – 전화 옴', '마지막 타이핑(지도앱)2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '문자앱 들어감3 – 전화 옴', '문자앱 들어감4 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '지도앱 들어감3 – 전화 옴', '지도앱 들어감2 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 통화앱 들어감1(incallui)', '문자앱 들어감2 – 통화앱 들어감1(incallui)', '문자앱 들어감3 – 통화앱 들어감1(incallui)', '문자앱 들어감4 – 통화앱 들어감1(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감1(incallui)', '지도앱 들어감3 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 지도앱 들어감2', '문자앱 들어감2 – 지도앱 들어감2', '문자앱 들어감3 – 지도앱 들어감2', '문자앱 들어감4 – 지도앱 들어감2', '마지막 타이핑(문자앱) – 지도앱 들어감2', '지도앱 들어감3 – 지도앱 들어감2', '문자앱 들어감2 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감4 – 마지막 타이핑(지도앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)2', '지도앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '지도앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감3', '지도앱 들어감3 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감3 – 문자앱 들어감4', '지도앱 들어감3 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '지도앱 들어감1 – 문자도착1', '마지막 타이핑(지도앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감1(incallui) – 문자도착1', '지도앱 들어감2 – 문자도착1', '마지막 타이핑(지도앱)2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '문자앱 들어감3 – 문자도착1', '문자앱 들어감4 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '지도앱 들어감3 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감1(incallui) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(지도앱)2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '문자앱 들어감3 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감3 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감1(incallui) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱)2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '문자앱 들어감3 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감3 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 지도앱 들어감1', '전화 옴 – 지도앱 들어감1', '통화앱 들어감1(incallui) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '마지막 타이핑(지도앱)2 – 지도앱 들어감1', '문자앱 들어감2 – 지도앱 들어감1', '문자앱 들어감3 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감3 – 지도앱 들어감1', '전화 옴 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 마지막 타이핑(지도앱)1', '지도앱 들어감2 – 마지막 타이핑(지도앱)1', '마지막 타이핑(지도앱)2 – 마지막 타이핑(지도앱)1', '문자앱 들어감2 – 마지막 타이핑(지도앱)1', '문자앱 들어감3 – 마지막 타이핑(지도앱)1', '문자앱 들어감4 – 마지막 타이핑(지도앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)1', '지도앱 들어감3 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 전화 옴', '지도앱 들어감2 – 전화 옴', '마지막 타이핑(지도앱)2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '문자앱 들어감3 – 전화 옴', '문자앱 들어감4 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '지도앱 들어감3 – 전화 옴', '지도앱 들어감2 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 통화앱 들어감1(incallui)', '문자앱 들어감2 – 통화앱 들어감1(incallui)', '문자앱 들어감3 – 통화앱 들어감1(incallui)', '문자앱 들어감4 – 통화앱 들어감1(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감1(incallui)', '지도앱 들어감3 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 지도앱 들어감2', '문자앱 들어감2 – 지도앱 들어감2', '문자앱 들어감3 – 지도앱 들어감2', '문자앱 들어감4 – 지도앱 들어감2', '마지막 타이핑(문자앱) – 지도앱 들어감2', '지도앱 들어감3 – 지도앱 들어감2', '문자앱 들어감2 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감4 – 마지막 타이핑(지도앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)2', '지도앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '지도앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감3', '지도앱 들어감3 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감3 – 문자앱 들어감4', '지도앱 들어감3 – 마지막 타이핑(문자앱)', '문자앱 들어감1 – 문자도착1', '문자앱 나옴1 – 문자도착1', '지도앱 들어감1 – 문자도착1', '마지막 타이핑(지도앱)1 – 문자도착1', '전화 옴 – 문자도착1', '통화앱 들어감1(incallui) – 문자도착1', '지도앱 들어감2 – 문자도착1', '마지막 타이핑(지도앱)2 – 문자도착1', '문자앱 들어감2 – 문자도착1', '문자앱 들어감3 – 문자도착1', '문자앱 들어감4 – 문자도착1', '마지막 타이핑(문자앱) – 문자도착1', '지도앱 들어감3 – 문자도착1', '문자앱 나옴1 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 들어감1', '마지막 타이핑(지도앱)1 – 문자앱 들어감1', '전화 옴 – 문자앱 들어감1', '통화앱 들어감1(incallui) – 문자앱 들어감1', '지도앱 들어감2 – 문자앱 들어감1', '마지막 타이핑(지도앱)2 – 문자앱 들어감1', '문자앱 들어감2 – 문자앱 들어감1', '문자앱 들어감3 – 문자앱 들어감1', '문자앱 들어감4 – 문자앱 들어감1', '마지막 타이핑(문자앱) – 문자앱 들어감1', '지도앱 들어감3 – 문자앱 들어감1', '지도앱 들어감1 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 문자앱 나옴1', '전화 옴 – 문자앱 나옴1', '통화앱 들어감1(incallui) – 문자앱 나옴1', '지도앱 들어감2 – 문자앱 나옴1', '마지막 타이핑(지도앱)2 – 문자앱 나옴1', '문자앱 들어감2 – 문자앱 나옴1', '문자앱 들어감3 – 문자앱 나옴1', '문자앱 들어감4 – 문자앱 나옴1', '마지막 타이핑(문자앱) – 문자앱 나옴1', '지도앱 들어감3 – 문자앱 나옴1', '마지막 타이핑(지도앱)1 – 지도앱 들어감1', '전화 옴 – 지도앱 들어감1', '통화앱 들어감1(incallui) – 지도앱 들어감1', '지도앱 들어감2 – 지도앱 들어감1', '마지막 타이핑(지도앱)2 – 지도앱 들어감1', '문자앱 들어감2 – 지도앱 들어감1', '문자앱 들어감3 – 지도앱 들어감1', '문자앱 들어감4 – 지도앱 들어감1', '마지막 타이핑(문자앱) – 지도앱 들어감1', '지도앱 들어감3 – 지도앱 들어감1', '전화 옴 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 마지막 타이핑(지도앱)1', '지도앱 들어감2 – 마지막 타이핑(지도앱)1', '마지막 타이핑(지도앱)2 – 마지막 타이핑(지도앱)1', '문자앱 들어감2 – 마지막 타이핑(지도앱)1', '문자앱 들어감3 – 마지막 타이핑(지도앱)1', '문자앱 들어감4 – 마지막 타이핑(지도앱)1', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)1', '지도앱 들어감3 – 마지막 타이핑(지도앱)1', '통화앱 들어감1(incallui) – 전화 옴', '지도앱 들어감2 – 전화 옴', '마지막 타이핑(지도앱)2 – 전화 옴', '문자앱 들어감2 – 전화 옴', '문자앱 들어감3 – 전화 옴', '문자앱 들어감4 – 전화 옴', '마지막 타이핑(문자앱) – 전화 옴', '지도앱 들어감3 – 전화 옴', '지도앱 들어감2 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 통화앱 들어감1(incallui)', '문자앱 들어감2 – 통화앱 들어감1(incallui)', '문자앱 들어감3 – 통화앱 들어감1(incallui)', '문자앱 들어감4 – 통화앱 들어감1(incallui)', '마지막 타이핑(문자앱) – 통화앱 들어감1(incallui)', '지도앱 들어감3 – 통화앱 들어감1(incallui)', '마지막 타이핑(지도앱)2 – 지도앱 들어감2', '문자앱 들어감2 – 지도앱 들어감2', '문자앱 들어감3 – 지도앱 들어감2', '문자앱 들어감4 – 지도앱 들어감2', '마지막 타이핑(문자앱) – 지도앱 들어감2', '지도앱 들어감3 – 지도앱 들어감2', '문자앱 들어감2 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감4 – 마지막 타이핑(지도앱)2', '마지막 타이핑(문자앱) – 마지막 타이핑(지도앱)2', '지도앱 들어감3 – 마지막 타이핑(지도앱)2', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '마지막 타이핑(문자앱) – 문자앱 들어감2', '지도앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감3', '지도앱 들어감3 – 문자앱 들어감3', '마지막 타이핑(문자앱) – 문자앱 들어감4', '지도앱 들어감3 – 문자앱 들어감4', '지도앱 들어감3 – 마지막 타이핑(문자앱)'])

# %% [markdown]
# # Phone_Register_E

# %%
phone_register_E.insert(0, 'Label', ['screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2 - 문자도착', '문자앱 들어감3 - 문자도착', '문자앱 들어감4 - 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감6 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2 - screen on', '문자앱 들어감3 - screen on', '문자앱 들어감4 - screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감6 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2 - screen unlock', '문자앱 들어감3 - screen unlock', '문자앱 들어감4 - screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감6 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감6 - 문자앱 들어감1', '문자앱 들어감2 - 연락처앱 들어감', '문자앱 들어감3 - 연락처앱 들어감', '문자앱 들어감4- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감6 - 연락처앱 들어감', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감6 - 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '전화앱 들어감(telecom) - 문자앱 들어감3', '통화앱 들어감(incallui) - 문자앱 들어감3', '문자앱 들어감6 - 문자앱 들어감3', '전화앱 들어감(telecom) - 문자앱 들어감4', '통화앱 들어감(incallui) - 문자앱 들어감4', '문자앱 들어감6 - 문자앱 들어감4', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감6 - 전화앱 들어감(telecom)', '문자앱 들어감6 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2 - 문자도착', '문자앱 들어감3 - 문자도착', '문자앱 들어감4 - 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감6 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2 - screen on', '문자앱 들어감3 - screen on', '문자앱 들어감4 - screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감6 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2 - screen unlock', '문자앱 들어감3 - screen unlock', '문자앱 들어감4 - screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감6 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감6 - 문자앱 들어감1', '문자앱 들어감2 - 연락처앱 들어감', '문자앱 들어감3 - 연락처앱 들어감', '문자앱 들어감4- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감6 - 연락처앱 들어감', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감6 - 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '전화앱 들어감(telecom) - 문자앱 들어감3', '통화앱 들어감(incallui) - 문자앱 들어감3', '문자앱 들어감6 - 문자앱 들어감3', '전화앱 들어감(telecom) - 문자앱 들어감4', '통화앱 들어감(incallui) - 문자앱 들어감4', '문자앱 들어감6 - 문자앱 들어감4', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감6 - 전화앱 들어감(telecom)', '문자앱 들어감6 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2 - 문자도착', '문자앱 들어감3 - 문자도착', '문자앱 들어감4 - 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감6 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2 - screen on', '문자앱 들어감3 - screen on', '문자앱 들어감4 - screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감6 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2 - screen unlock', '문자앱 들어감3 - screen unlock', '문자앱 들어감4 - screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감6 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감6 - 문자앱 들어감1', '문자앱 들어감2 - 연락처앱 들어감', '문자앱 들어감3 - 연락처앱 들어감', '문자앱 들어감4- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감6 - 연락처앱 들어감', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감6 - 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '전화앱 들어감(telecom) - 문자앱 들어감3', '통화앱 들어감(incallui) - 문자앱 들어감3', '문자앱 들어감6 - 문자앱 들어감3', '전화앱 들어감(telecom) - 문자앱 들어감4', '통화앱 들어감(incallui) - 문자앱 들어감4', '문자앱 들어감6 - 문자앱 들어감4', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감6 - 전화앱 들어감(telecom)', '문자앱 들어감6 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2 - 문자도착', '문자앱 들어감3 - 문자도착', '문자앱 들어감4 - 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감6 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2 - screen on', '문자앱 들어감3 - screen on', '문자앱 들어감4 - screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감6 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2 - screen unlock', '문자앱 들어감3 - screen unlock', '문자앱 들어감4 - screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감6 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감6 - 문자앱 들어감1', '문자앱 들어감2 - 연락처앱 들어감', '문자앱 들어감3 - 연락처앱 들어감', '문자앱 들어감4- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감6 - 연락처앱 들어감', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감6 - 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '전화앱 들어감(telecom) - 문자앱 들어감3', '통화앱 들어감(incallui) - 문자앱 들어감3', '문자앱 들어감6 - 문자앱 들어감3', '전화앱 들어감(telecom) - 문자앱 들어감4', '통화앱 들어감(incallui) - 문자앱 들어감4', '문자앱 들어감6 - 문자앱 들어감4', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감6 - 전화앱 들어감(telecom)', '문자앱 들어감6 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2 - 문자도착', '문자앱 들어감3 - 문자도착', '문자앱 들어감4 - 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감6 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2 - screen on', '문자앱 들어감3 - screen on', '문자앱 들어감4 - screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감6 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2 - screen unlock', '문자앱 들어감3 - screen unlock', '문자앱 들어감4 - screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감6 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감6 - 문자앱 들어감1', '문자앱 들어감2 - 연락처앱 들어감', '문자앱 들어감3 - 연락처앱 들어감', '문자앱 들어감4- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감6 - 연락처앱 들어감', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감6 - 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '전화앱 들어감(telecom) - 문자앱 들어감3', '통화앱 들어감(incallui) - 문자앱 들어감3', '문자앱 들어감6 - 문자앱 들어감3', '전화앱 들어감(telecom) - 문자앱 들어감4', '통화앱 들어감(incallui) - 문자앱 들어감4', '문자앱 들어감6 - 문자앱 들어감4', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감6 - 전화앱 들어감(telecom)', '문자앱 들어감6 - 통화앱 들어감(incallui)', 'screen on - 문자도착', 'screen unlock - 문자도착', '문자앱 들어감1 - 문자도착', '연락처앱 들어감 - 문자도착', '문자앱 들어감2 - 문자도착', '문자앱 들어감3 - 문자도착', '문자앱 들어감4 - 문자도착', '전화앱 들어감(telecom) - 문자도착', '통화앱 들어감(incallui) - 문자도착', '문자앱 들어감6 - 문자도착', 'screen unlock - screen on', '문자앱 들어감1 - screen on', '연락처앱 들어감 - screen on', '문자앱 들어감2 - screen on', '문자앱 들어감3 - screen on', '문자앱 들어감4 - screen on', '전화앱 들어감(telecom) - screen on', '통화앱 들어감(incallui) - screen on', '문자앱 들어감6 - screen on', '문자앱 들어감1 - screen unlock', '연락처앱 들어감 - screen unlock', '문자앱 들어감2 - screen unlock', '문자앱 들어감3 - screen unlock', '문자앱 들어감4 - screen unlock', '전화앱 들어감(telecom) - screen unlock', '통화앱 들어감(incallui) - screen unlock', '문자앱 들어감6 - screen unlock', '연락처앱 들어감 - 문자앱 들어감1', '문자앱 들어감2 - 문자앱 들어감1', '문자앱 들어감3 - 문자앱 들어감1', '문자앱 들어감4 - 문자앱 들어감1', '전화앱 들어감(telecom) - 문자앱 들어감1', '통화앱 들어감(incallui) - 문자앱 들어감1', '문자앱 들어감6 - 문자앱 들어감1', '문자앱 들어감2 - 연락처앱 들어감', '문자앱 들어감3 - 연락처앱 들어감', '문자앱 들어감4- 연락처앱 들어감', '전화앱 들어감(telecom) - 연락처앱 들어감', '통화앱 들어감(incallui) - 연락처앱 들어감', '문자앱 들어감6 - 연락처앱 들어감', '문자앱 들어감3 – 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감2', '전화앱 들어감(telecom) - 문자앱 들어감2', '통화앱 들어감(incallui) - 문자앱 들어감2', '문자앱 들어감6 - 문자앱 들어감2', '문자앱 들어감4 – 문자앱 들어감3', '전화앱 들어감(telecom) - 문자앱 들어감3', '통화앱 들어감(incallui) - 문자앱 들어감3', '문자앱 들어감6 - 문자앱 들어감3', '전화앱 들어감(telecom) - 문자앱 들어감4', '통화앱 들어감(incallui) - 문자앱 들어감4', '문자앱 들어감6 - 문자앱 들어감4', '통화앱 들어감(incallui) - 전화앱 들어감(telecom)', '문자앱 들어감6 - 전화앱 들어감(telecom)', '문자앱 들어감6 - 통화앱 들어감(incallui)'])

# %% [markdown]
# # Camera_E

# %%
camera_E.insert(0, 'Label', ['문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감', '문자앱 들어감 - 문자도착', '문자앱 나옴 - 문자도착', '카메라 들어감1 - 문자도착', '갤러리앱 들어감 - 문자도착', '카메라앱 들어감2 - 문자도착', '문자앱 나옴 - 문자앱 들어감', '카메라 들어감1 - 문자앱 들어감', '갤러리앱 들어감 - 문자앱 들어감', '카메라앱 들어감2 - 문자앱 들어감', '카메라 들어감1 - 문자앱 나옴', '갤러리앱 들어감 - 문자앱 나옴', '카메라앱 들어감2 - 문자앱 나옴', '갤러리앱 들어감 - 카메라 들어감1', '카메라앱 들어감2 - 카메라 들어감1', '카메라앱 들어감2 - 갤러리앱 들어감'])

# %% [markdown]
# # Phone_reigster_English_version

# %%
phone_register.insert(0,'Label',['SMS_NOTI_TRUE - MESSAGE_INBOX', 'SCREEN_ON - MESSAGE_INBOX', 'SCREEN_UNLOCK - MESSAGE_INBOX', 'SMS_ACITIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACITIVITY_PAUSED 1 - MESSAGE_INBOX', 'CONTACT_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CONTACT_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'TELECOM_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_OUTGOING - MESSAGE_INBOX', 'TELECOM_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'SCREEN_ON - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SMS_NOTI_TRUE', 'SMS_ACITIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACITIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_OUTGOING - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_ON', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_ON', 'CONTACT_ACTIVITY_RESUMED - SCREEN_ON', 'CONTACT_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_ON', 'TELECOM_ACTIVITY_RESUMED - SCREEN_ON', 'CALL_LOG_OUTGOING - SCREEN_ON', 'TELECOM_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_ON', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_ON', 'INCALLUI_NOTI_TRUE - SCREEN_ON', 'INCALLUI_NOTI_FALSE - SCREEN_ON', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CALL_LOG_OUTGOING - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'INCALLUI_NOTI_TRUE - SCREEN_UNLOCK', 'INCALLUI_NOTI_FALSE - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_PAUSED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_RESUMED - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_TRUE - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_FALSE - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SCREEN_ON - MESSAGE_INBOX', 'SCREEN_UNLOCK - MESSAGE_INBOX', 'SMS_ACITIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACITIVITY_PAUSED 1 - MESSAGE_INBOX', 'CONTACT_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CONTACT_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'TELECOM_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_OUTGOING - MESSAGE_INBOX', 'TELECOM_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'SCREEN_ON - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SMS_NOTI_TRUE', 'SMS_ACITIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACITIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_OUTGOING - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_ON', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_ON', 'CONTACT_ACTIVITY_RESUMED - SCREEN_ON', 'CONTACT_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_ON', 'TELECOM_ACTIVITY_RESUMED - SCREEN_ON', 'CALL_LOG_OUTGOING - SCREEN_ON', 'TELECOM_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_ON', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_ON', 'INCALLUI_NOTI_TRUE - SCREEN_ON', 'INCALLUI_NOTI_FALSE - SCREEN_ON', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CALL_LOG_OUTGOING - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'INCALLUI_NOTI_TRUE - SCREEN_UNLOCK', 'INCALLUI_NOTI_FALSE - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_PAUSED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_RESUMED - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_TRUE - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_FALSE - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SCREEN_ON - MESSAGE_INBOX', 'SCREEN_UNLOCK - MESSAGE_INBOX', 'SMS_ACITIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACITIVITY_PAUSED 1 - MESSAGE_INBOX', 'CONTACT_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CONTACT_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'TELECOM_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_OUTGOING - MESSAGE_INBOX', 'TELECOM_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'SCREEN_ON - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SMS_NOTI_TRUE', 'SMS_ACITIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACITIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_OUTGOING - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_ON', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_ON', 'CONTACT_ACTIVITY_RESUMED - SCREEN_ON', 'CONTACT_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_ON', 'TELECOM_ACTIVITY_RESUMED - SCREEN_ON', 'CALL_LOG_OUTGOING - SCREEN_ON', 'TELECOM_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_ON', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_ON', 'INCALLUI_NOTI_TRUE - SCREEN_ON', 'INCALLUI_NOTI_FALSE - SCREEN_ON', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CALL_LOG_OUTGOING - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'INCALLUI_NOTI_TRUE - SCREEN_UNLOCK', 'INCALLUI_NOTI_FALSE - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_PAUSED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_RESUMED - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_TRUE - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_FALSE - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SCREEN_ON - MESSAGE_INBOX', 'SCREEN_UNLOCK - MESSAGE_INBOX', 'SMS_ACITIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACITIVITY_PAUSED 1 - MESSAGE_INBOX', 'CONTACT_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CONTACT_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'TELECOM_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_OUTGOING - MESSAGE_INBOX', 'TELECOM_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'SCREEN_ON - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SMS_NOTI_TRUE', 'SMS_ACITIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACITIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_OUTGOING - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_ON', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_ON', 'CONTACT_ACTIVITY_RESUMED - SCREEN_ON', 'CONTACT_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_ON', 'TELECOM_ACTIVITY_RESUMED - SCREEN_ON', 'CALL_LOG_OUTGOING - SCREEN_ON', 'TELECOM_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_ON', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_ON', 'INCALLUI_NOTI_TRUE - SCREEN_ON', 'INCALLUI_NOTI_FALSE - SCREEN_ON', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CALL_LOG_OUTGOING - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'INCALLUI_NOTI_TRUE - SCREEN_UNLOCK', 'INCALLUI_NOTI_FALSE - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_PAUSED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_RESUMED - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_TRUE - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_FALSE - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SCREEN_ON - MESSAGE_INBOX', 'SCREEN_UNLOCK - MESSAGE_INBOX', 'SMS_ACITIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACITIVITY_PAUSED 1 - MESSAGE_INBOX', 'CONTACT_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CONTACT_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'TELECOM_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_OUTGOING - MESSAGE_INBOX', 'TELECOM_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'SCREEN_ON - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SMS_NOTI_TRUE', 'SMS_ACITIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACITIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_OUTGOING - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_ON', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_ON', 'CONTACT_ACTIVITY_RESUMED - SCREEN_ON', 'CONTACT_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_ON', 'TELECOM_ACTIVITY_RESUMED - SCREEN_ON', 'CALL_LOG_OUTGOING - SCREEN_ON', 'TELECOM_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_ON', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_ON', 'INCALLUI_NOTI_TRUE - SCREEN_ON', 'INCALLUI_NOTI_FALSE - SCREEN_ON', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CALL_LOG_OUTGOING - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'INCALLUI_NOTI_TRUE - SCREEN_UNLOCK', 'INCALLUI_NOTI_FALSE - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_PAUSED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_RESUMED - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_TRUE - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_FALSE - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SCREEN_ON - MESSAGE_INBOX', 'SCREEN_UNLOCK - MESSAGE_INBOX', 'SMS_ACITIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACITIVITY_PAUSED 1 - MESSAGE_INBOX', 'CONTACT_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CONTACT_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'TELECOM_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_OUTGOING - MESSAGE_INBOX', 'TELECOM_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'SCREEN_ON - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SMS_NOTI_TRUE', 'SMS_ACITIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACITIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_OUTGOING - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_ON', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_ON', 'CONTACT_ACTIVITY_RESUMED - SCREEN_ON', 'CONTACT_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_ON', 'TELECOM_ACTIVITY_RESUMED - SCREEN_ON', 'CALL_LOG_OUTGOING - SCREEN_ON', 'TELECOM_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_ON', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_ON', 'INCALLUI_NOTI_TRUE - SCREEN_ON', 'INCALLUI_NOTI_FALSE - SCREEN_ON', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CALL_LOG_OUTGOING - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'INCALLUI_NOTI_TRUE - SCREEN_UNLOCK', 'INCALLUI_NOTI_FALSE - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_PAUSED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_RESUMED - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_TRUE - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_FALSE - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SCREEN_ON - MESSAGE_INBOX', 'SCREEN_UNLOCK - MESSAGE_INBOX', 'SMS_ACITIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACITIVITY_PAUSED 1 - MESSAGE_INBOX', 'CONTACT_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CONTACT_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'TELECOM_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_OUTGOING - MESSAGE_INBOX', 'TELECOM_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'SCREEN_ON - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SMS_NOTI_TRUE', 'SMS_ACITIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACITIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_OUTGOING - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_ON', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_ON', 'CONTACT_ACTIVITY_RESUMED - SCREEN_ON', 'CONTACT_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_ON', 'TELECOM_ACTIVITY_RESUMED - SCREEN_ON', 'CALL_LOG_OUTGOING - SCREEN_ON', 'TELECOM_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_ON', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_ON', 'INCALLUI_NOTI_TRUE - SCREEN_ON', 'INCALLUI_NOTI_FALSE - SCREEN_ON', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CALL_LOG_OUTGOING - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'INCALLUI_NOTI_TRUE - SCREEN_UNLOCK', 'INCALLUI_NOTI_FALSE - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_PAUSED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_RESUMED - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_TRUE - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_FALSE - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SCREEN_ON - MESSAGE_INBOX', 'SCREEN_UNLOCK - MESSAGE_INBOX', 'SMS_ACITIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACITIVITY_PAUSED 1 - MESSAGE_INBOX', 'CONTACT_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CONTACT_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'TELECOM_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_OUTGOING - MESSAGE_INBOX', 'TELECOM_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'SCREEN_ON - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SMS_NOTI_TRUE', 'SMS_ACITIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACITIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_OUTGOING - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_ON', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_ON', 'CONTACT_ACTIVITY_RESUMED - SCREEN_ON', 'CONTACT_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_ON', 'TELECOM_ACTIVITY_RESUMED - SCREEN_ON', 'CALL_LOG_OUTGOING - SCREEN_ON', 'TELECOM_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_ON', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_ON', 'INCALLUI_NOTI_TRUE - SCREEN_ON', 'INCALLUI_NOTI_FALSE - SCREEN_ON', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CALL_LOG_OUTGOING - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'INCALLUI_NOTI_TRUE - SCREEN_UNLOCK', 'INCALLUI_NOTI_FALSE - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_PAUSED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_RESUMED - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_TRUE - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_FALSE - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SCREEN_ON - MESSAGE_INBOX', 'SCREEN_UNLOCK - MESSAGE_INBOX', 'SMS_ACITIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACITIVITY_PAUSED 1 - MESSAGE_INBOX', 'CONTACT_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CONTACT_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'TELECOM_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_OUTGOING - MESSAGE_INBOX', 'TELECOM_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'SCREEN_ON - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SMS_NOTI_TRUE', 'SMS_ACITIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACITIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CONTACT_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_OUTGOING - SMS_NOTI_TRUE', 'TELECOM_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'SCREEN_UNLOCK - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_ON', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_ON', 'CONTACT_ACTIVITY_RESUMED - SCREEN_ON', 'CONTACT_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_ON', 'TELECOM_ACTIVITY_RESUMED - SCREEN_ON', 'CALL_LOG_OUTGOING - SCREEN_ON', 'TELECOM_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_ON', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_ON', 'INCALLUI_NOTI_TRUE - SCREEN_ON', 'INCALLUI_NOTI_FALSE - SCREEN_ON', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_ON', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_ON', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_ON', 'SMS_ACITIVITY_RESUMED 1 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CONTACT_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 2 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 2 - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'CALL_LOG_OUTGOING - SCREEN_UNLOCK', 'TELECOM_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 3 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 3 - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_RESUMED - SCREEN_UNLOCK', 'INCALLUI_NOTI_TRUE - SCREEN_UNLOCK', 'INCALLUI_NOTI_FALSE - SCREEN_UNLOCK', 'INCALLUI_ACTIVITY_PAUSED - SCREEN_UNLOCK', 'SMS_ACTIVITY_RESUMED 4 - SCREEN_UNLOCK', 'SMS_ACTIVITY_PAUSED 4 - SCREEN_UNLOCK', 'SMS_ACITIVITY_PAUSED 1 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_RESUMED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_RESUMED 1', 'CONTACT_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'CALL_LOG_OUTGOING - SMS_ACITIVITY_PAUSED 1', 'TELECOM_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - SMS_ACITIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACITIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACITIVITY_PAUSED 1', 'CONTACT_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 2 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'CALL_LOG_OUTGOING - CONTACT_ACTIVITY_PAUSED', 'TELECOM_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 3 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - CONTACT_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - CONTACT_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'TELECOM_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - SMS_ACTIVITY_PAUSED 2', 'TELECOM_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 2', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'CALL_LOG_OUTGOING - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_RESUMED', 'TELECOM_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_RESUMED - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_TRUE - CALL_LOG_OUTGOING', 'INCALLUI_NOTI_FALSE - CALL_LOG_OUTGOING', 'INCALLUI_ACTIVITY_PAUSED - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_OUTGOING', 'SMS_ACTIVITY_RESUMED 3 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_RESUMED - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_TRUE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_NOTI_FALSE - TELECOM_ACTIVITY_PAUSED', 'INCALLUI_ACTIVITY_PAUSED - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_RESUMED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - TELECOM_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'INCALLUI_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'INCALLUI_NOTI_TRUE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4'])
phone_receive.insert(0,'Label',['SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_REJECTED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'KEY_LOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'KEY_LOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED', 'KEY_LOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - CALL_LOG_REJECTED', 'KEY_LOG - CALL_LOG_REJECTED', 'MESSAGE_SENT - CALL_LOG_REJECTED', 'SMS_ACTIVITY_PAUSED - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_TRUE', 'MESSAGE_SENT - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - KEY_LOG', 'SMS_ACTIVITY_PAUSED - KEY_LOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_REJECTED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'KEY_LOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'KEY_LOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED', 'KEY_LOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - CALL_LOG_REJECTED', 'KEY_LOG - CALL_LOG_REJECTED', 'MESSAGE_SENT - CALL_LOG_REJECTED', 'SMS_ACTIVITY_PAUSED - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_TRUE', 'MESSAGE_SENT - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - KEY_LOG', 'SMS_ACTIVITY_PAUSED - KEY_LOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_REJECTED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'KEY_LOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'KEY_LOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED', 'KEY_LOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - CALL_LOG_REJECTED', 'KEY_LOG - CALL_LOG_REJECTED', 'MESSAGE_SENT - CALL_LOG_REJECTED', 'SMS_ACTIVITY_PAUSED - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_TRUE', 'MESSAGE_SENT - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - KEY_LOG', 'SMS_ACTIVITY_PAUSED - KEY_LOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_REJECTED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'KEY_LOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'KEY_LOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED', 'KEY_LOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - CALL_LOG_REJECTED', 'KEY_LOG - CALL_LOG_REJECTED', 'MESSAGE_SENT - CALL_LOG_REJECTED', 'SMS_ACTIVITY_PAUSED - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_TRUE', 'MESSAGE_SENT - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - KEY_LOG', 'SMS_ACTIVITY_PAUSED - KEY_LOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_REJECTED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'KEY_LOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'KEY_LOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED', 'KEY_LOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - CALL_LOG_REJECTED', 'KEY_LOG - CALL_LOG_REJECTED', 'MESSAGE_SENT - CALL_LOG_REJECTED', 'SMS_ACTIVITY_PAUSED - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_TRUE', 'MESSAGE_SENT - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - KEY_LOG', 'SMS_ACTIVITY_PAUSED - KEY_LOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_REJECTED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'KEY_LOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'KEY_LOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED', 'KEY_LOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - CALL_LOG_REJECTED', 'KEY_LOG - CALL_LOG_REJECTED', 'MESSAGE_SENT - CALL_LOG_REJECTED', 'SMS_ACTIVITY_PAUSED - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_TRUE', 'MESSAGE_SENT - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - KEY_LOG', 'SMS_ACTIVITY_PAUSED - KEY_LOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_REJECTED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'KEY_LOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'KEY_LOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED', 'KEY_LOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - CALL_LOG_REJECTED', 'KEY_LOG - CALL_LOG_REJECTED', 'MESSAGE_SENT - CALL_LOG_REJECTED', 'SMS_ACTIVITY_PAUSED - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_TRUE', 'MESSAGE_SENT - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - KEY_LOG', 'SMS_ACTIVITY_PAUSED - KEY_LOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_REJECTED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'KEY_LOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'KEY_LOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED', 'KEY_LOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - CALL_LOG_REJECTED', 'KEY_LOG - CALL_LOG_REJECTED', 'MESSAGE_SENT - CALL_LOG_REJECTED', 'SMS_ACTIVITY_PAUSED - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_TRUE', 'MESSAGE_SENT - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - KEY_LOG', 'SMS_ACTIVITY_PAUSED - KEY_LOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'CALL_LOG_REJECTED - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'KEY_LOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'KEY_LOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CALL_LOG_REJECTED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED', 'KEY_LOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'INCALLUI_NOTI_TRUE - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - CALL_LOG_REJECTED', 'KEY_LOG - CALL_LOG_REJECTED', 'MESSAGE_SENT - CALL_LOG_REJECTED', 'SMS_ACTIVITY_PAUSED - CALL_LOG_REJECTED', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_TRUE', 'MESSAGE_SENT - INCALLUI_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_TRUE', 'KEY_LOG - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT - KEY_LOG', 'SMS_ACTIVITY_PAUSED - KEY_LOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT'])
#sms_reply.insert(0,'Label',[])
sms_reply.insert(0,'Label',['SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'KEYLOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'KEYLOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE','KEYLOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED','MESSAGE_SENT - KEYLOG', 'SMS_ACTIVITY_PAUSED - KEYLOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'KEYLOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'KEYLOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE','KEYLOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED','MESSAGE_SENT - KEYLOG', 'SMS_ACTIVITY_PAUSED - KEYLOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'KEYLOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'KEYLOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE','KEYLOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED','MESSAGE_SENT - KEYLOG', 'SMS_ACTIVITY_PAUSED - KEYLOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'KEYLOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'KEYLOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE','KEYLOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED','MESSAGE_SENT - KEYLOG', 'SMS_ACTIVITY_PAUSED - KEYLOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'KEYLOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'KEYLOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE','KEYLOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED','MESSAGE_SENT - KEYLOG', 'SMS_ACTIVITY_PAUSED - KEYLOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'KEYLOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'KEYLOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE','KEYLOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED','MESSAGE_SENT - KEYLOG', 'SMS_ACTIVITY_PAUSED - KEYLOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'KEYLOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'KEYLOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE','KEYLOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED','MESSAGE_SENT - KEYLOG', 'SMS_ACTIVITY_PAUSED - KEYLOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'KEYLOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'KEYLOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE','KEYLOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED','MESSAGE_SENT - KEYLOG', 'SMS_ACTIVITY_PAUSED - KEYLOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'KEYLOG - MESSAGE_INBOX', 'MESSAGE_SENT - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'KEYLOG - SMS_NOTI_TRUE', 'MESSAGE_SENT - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE','KEYLOG - SMS_ACTIVITY_RESUMED', 'MESSAGE_SENT - SMS_ACTIVITY_RESUMED', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED','MESSAGE_SENT - KEYLOG', 'SMS_ACTIVITY_PAUSED - KEYLOG', 'SMS_ACTIVITY_PAUSED - MESSAGE_SENT'])
camera.insert(0,'Label',['SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'MEDIA 1 - MESSAGE_INBOX', 'MEDIA 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'GALLERY_ACTIVITY_RESUMED - MESSAGE_INBOX', 'GALLERY_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'MEDIA 1 - SMS_NOTI_TRUE', 'MEDIA 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 1 - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 1', 'GALLERY_ACTIVITY_RESUMED - MEDIA 1', 'GALLERY_ACTIVITY_PAUSED - MEDIA 1', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - MEDIA 2', 'GALLERY_ACTIVITY_PAUSED - MEDIA 2', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 2', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 2', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'MEDIA 1 - MESSAGE_INBOX', 'MEDIA 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'GALLERY_ACTIVITY_RESUMED - MESSAGE_INBOX', 'GALLERY_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'MEDIA 1 - SMS_NOTI_TRUE', 'MEDIA 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 1 - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 1', 'GALLERY_ACTIVITY_RESUMED - MEDIA 1', 'GALLERY_ACTIVITY_PAUSED - MEDIA 1', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - MEDIA 2', 'GALLERY_ACTIVITY_PAUSED - MEDIA 2', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 2', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 2', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'MEDIA 1 - MESSAGE_INBOX', 'MEDIA 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'GALLERY_ACTIVITY_RESUMED - MESSAGE_INBOX', 'GALLERY_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'MEDIA 1 - SMS_NOTI_TRUE', 'MEDIA 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 1 - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 1', 'GALLERY_ACTIVITY_RESUMED - MEDIA 1', 'GALLERY_ACTIVITY_PAUSED - MEDIA 1', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - MEDIA 2', 'GALLERY_ACTIVITY_PAUSED - MEDIA 2', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 2', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 2', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'MEDIA 1 - MESSAGE_INBOX', 'MEDIA 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'GALLERY_ACTIVITY_RESUMED - MESSAGE_INBOX', 'GALLERY_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'MEDIA 1 - SMS_NOTI_TRUE', 'MEDIA 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 1 - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 1', 'GALLERY_ACTIVITY_RESUMED - MEDIA 1', 'GALLERY_ACTIVITY_PAUSED - MEDIA 1', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - MEDIA 2', 'GALLERY_ACTIVITY_PAUSED - MEDIA 2', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 2', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 2', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'MEDIA 1 - MESSAGE_INBOX', 'MEDIA 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'GALLERY_ACTIVITY_RESUMED - MESSAGE_INBOX', 'GALLERY_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'MEDIA 1 - SMS_NOTI_TRUE', 'MEDIA 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 1 - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 1', 'GALLERY_ACTIVITY_RESUMED - MEDIA 1', 'GALLERY_ACTIVITY_PAUSED - MEDIA 1', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - MEDIA 2', 'GALLERY_ACTIVITY_PAUSED - MEDIA 2', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 2', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 2', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'MEDIA 1 - MESSAGE_INBOX', 'MEDIA 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'GALLERY_ACTIVITY_RESUMED - MESSAGE_INBOX', 'GALLERY_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'MEDIA 1 - SMS_NOTI_TRUE', 'MEDIA 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 1 - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 1', 'GALLERY_ACTIVITY_RESUMED - MEDIA 1', 'GALLERY_ACTIVITY_PAUSED - MEDIA 1', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - MEDIA 2', 'GALLERY_ACTIVITY_PAUSED - MEDIA 2', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 2', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 2', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'MEDIA 1 - MESSAGE_INBOX', 'MEDIA 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'GALLERY_ACTIVITY_RESUMED - MESSAGE_INBOX', 'GALLERY_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'MEDIA 1 - SMS_NOTI_TRUE', 'MEDIA 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 1 - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 1', 'GALLERY_ACTIVITY_RESUMED - MEDIA 1', 'GALLERY_ACTIVITY_PAUSED - MEDIA 1', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - MEDIA 2', 'GALLERY_ACTIVITY_PAUSED - MEDIA 2', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 2', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 2', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'MEDIA 1 - MESSAGE_INBOX', 'MEDIA 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'GALLERY_ACTIVITY_RESUMED - MESSAGE_INBOX', 'GALLERY_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'MEDIA 1 - SMS_NOTI_TRUE', 'MEDIA 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 1 - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 1', 'GALLERY_ACTIVITY_RESUMED - MEDIA 1', 'GALLERY_ACTIVITY_PAUSED - MEDIA 1', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - MEDIA 2', 'GALLERY_ACTIVITY_PAUSED - MEDIA 2', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 2', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 2', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'MEDIA 1 - MESSAGE_INBOX', 'MEDIA 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'GALLERY_ACTIVITY_RESUMED - MESSAGE_INBOX', 'GALLERY_ACTIVITY_PAUSED - MESSAGE_INBOX', 'CAMERA_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'CAMERA_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'MEDIA 1 - SMS_NOTI_TRUE', 'MEDIA 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_RESUMED - SMS_NOTI_TRUE', 'GALLERY_ACTIVITY_PAUSED - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 1 - SMS_ACTIVITY_RESUMED', 'MEDIA 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_RESUMED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - SMS_ACTIVITY_PAUSED', 'MEDIA 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_RESUMED - SMS_ACTIVITY_PAUSED', 'GALLERY_ACTIVITY_PAUSED - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED', 'MEDIA 1 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 1 - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_RESUMED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_RESUMED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 1', 'MEDIA 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 1', 'GALLERY_ACTIVITY_RESUMED - MEDIA 1', 'GALLERY_ACTIVITY_PAUSED - MEDIA 1', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 1', 'CAMERA_ACTIVITY_PAUSED 1 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - MEDIA 2', 'GALLERY_ACTIVITY_PAUSED - MEDIA 2', 'CAMERA_ACTIVITY_RESUMED 2 - MEDIA 2', 'CAMERA_ACTIVITY_PAUSED 2 - MEDIA 2', 'GALLERY_ACTIVITY_RESUMED - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_RESUMED 2 - CAMERA_ACTIVITY_PAUSED 1', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_PAUSED 1', 'GALLERY_ACTIVITY_PAUSED - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_RESUMED', 'CAMERA_ACTIVITY_RESUMED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - GALLERY_ACTIVITY_PAUSED', 'CAMERA_ACTIVITY_PAUSED 2 - CAMERA_ACTIVITY_RESUMED 2'])

#location_searching.insert(0,'Label',[])
location_switching.insert(0, 'Label', ['SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'KEY_LOG 1 - MESSAGE_INBOX', 'CALL_LOG_INCOMING - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 2 - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'KEY_LOG 2 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'MESSAGE_SENT 1 - MESSAGE_INBOX', 'KEY_LOG 3 - MESSAGE_INBOX', 'MESSAGE_SENT 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'KEY_LOG 1 - SMS_NOTI_TRUE', 'CALL_LOG_INCOMING - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 2 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'KEY_LOG 2 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'MESSAGE_SENT 1 - SMS_NOTI_TRUE', 'KEY_LOG 3 - SMS_NOTI_TRUE', 'MESSAGE_SENT 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ',  'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_PAUSED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 2 - KEY_LOG 1 ', 'INCALLUI_NOTI_FALSE - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'KEY_LOG 2 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 1 ', 'MESSAGE_SENT 1 - KEY_LOG 1 ', 'KEY_LOG 3 - KEY_LOG 1 ', 'MESSAGE_SENT 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 1 ',  'INCALLUI_NOTI_TRUE 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_RESUMED 1 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_TRUE 2 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_FALSE - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'KEY_LOG 2 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING ', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_INCOMING', 'MESSAGE_SENT 1 - CALL_LOG_INCOMING', 'KEY_LOG 3 - CALL_LOG_INCOMING', 'MESSAGE_SENT 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING',  'MAP_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1',  'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'KEY_LOG 2 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 1 - INCALLUI_NOTI_FALSE', 'KEY_LOG 3 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 2', 'MESSAGE_SENT 1 - KEY_LOG 2', 'KEY_LOG 3 - KEY_LOG 2', 'MESSAGE_SENT 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 2', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 3', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 3', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 4', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 4', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - MESSAGE_SENT 1', 'MESSAGE_SENT 2 - MESSAGE_SENT 1', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 1', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 1', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 1',  'MESSAGE_SENT 2 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 3', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 3', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 3', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'KEY_LOG 1 - MESSAGE_INBOX', 'CALL_LOG_INCOMING - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 2 - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'KEY_LOG 2 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'MESSAGE_SENT 1 - MESSAGE_INBOX', 'KEY_LOG 3 - MESSAGE_INBOX', 'MESSAGE_SENT 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'KEY_LOG 1 - SMS_NOTI_TRUE', 'CALL_LOG_INCOMING - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 2 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'KEY_LOG 2 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'MESSAGE_SENT 1 - SMS_NOTI_TRUE', 'KEY_LOG 3 - SMS_NOTI_TRUE', 'MESSAGE_SENT 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ',  'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_PAUSED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 2 - KEY_LOG 1 ', 'INCALLUI_NOTI_FALSE - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'KEY_LOG 2 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 1 ', 'MESSAGE_SENT 1 - KEY_LOG 1 ', 'KEY_LOG 3 - KEY_LOG 1 ', 'MESSAGE_SENT 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 1 ',  'INCALLUI_NOTI_TRUE 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_RESUMED 1 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_TRUE 2 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_FALSE - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'KEY_LOG 2 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING ', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_INCOMING', 'MESSAGE_SENT 1 - CALL_LOG_INCOMING', 'KEY_LOG 3 - CALL_LOG_INCOMING', 'MESSAGE_SENT 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING',  'MAP_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1',  'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'KEY_LOG 2 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 1 - INCALLUI_NOTI_FALSE', 'KEY_LOG 3 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 2', 'MESSAGE_SENT 1 - KEY_LOG 2', 'KEY_LOG 3 - KEY_LOG 2', 'MESSAGE_SENT 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 2', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 3', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 3', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 4', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 4', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - MESSAGE_SENT 1', 'MESSAGE_SENT 2 - MESSAGE_SENT 1', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 1', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 1', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 1',  'MESSAGE_SENT 2 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 3', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 3', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 3', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'KEY_LOG 1 - MESSAGE_INBOX', 'CALL_LOG_INCOMING - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 2 - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'KEY_LOG 2 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'MESSAGE_SENT 1 - MESSAGE_INBOX', 'KEY_LOG 3 - MESSAGE_INBOX', 'MESSAGE_SENT 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'KEY_LOG 1 - SMS_NOTI_TRUE', 'CALL_LOG_INCOMING - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 2 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'KEY_LOG 2 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'MESSAGE_SENT 1 - SMS_NOTI_TRUE', 'KEY_LOG 3 - SMS_NOTI_TRUE', 'MESSAGE_SENT 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ',  'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_PAUSED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 2 - KEY_LOG 1 ', 'INCALLUI_NOTI_FALSE - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'KEY_LOG 2 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 1 ', 'MESSAGE_SENT 1 - KEY_LOG 1 ', 'KEY_LOG 3 - KEY_LOG 1 ', 'MESSAGE_SENT 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 1 ',  'INCALLUI_NOTI_TRUE 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_RESUMED 1 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_TRUE 2 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_FALSE - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'KEY_LOG 2 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING ', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_INCOMING', 'MESSAGE_SENT 1 - CALL_LOG_INCOMING', 'KEY_LOG 3 - CALL_LOG_INCOMING', 'MESSAGE_SENT 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING',  'MAP_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1',  'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'KEY_LOG 2 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 1 - INCALLUI_NOTI_FALSE', 'KEY_LOG 3 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 2', 'MESSAGE_SENT 1 - KEY_LOG 2', 'KEY_LOG 3 - KEY_LOG 2', 'MESSAGE_SENT 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 2', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 3', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 3', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 4', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 4', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - MESSAGE_SENT 1', 'MESSAGE_SENT 2 - MESSAGE_SENT 1', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 1', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 1', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 1',  'MESSAGE_SENT 2 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 3', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 3', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 3', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'KEY_LOG 1 - MESSAGE_INBOX', 'CALL_LOG_INCOMING - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 2 - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'KEY_LOG 2 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'MESSAGE_SENT 1 - MESSAGE_INBOX', 'KEY_LOG 3 - MESSAGE_INBOX', 'MESSAGE_SENT 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'KEY_LOG 1 - SMS_NOTI_TRUE', 'CALL_LOG_INCOMING - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 2 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'KEY_LOG 2 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'MESSAGE_SENT 1 - SMS_NOTI_TRUE', 'KEY_LOG 3 - SMS_NOTI_TRUE', 'MESSAGE_SENT 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ',  'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_PAUSED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 2 - KEY_LOG 1 ', 'INCALLUI_NOTI_FALSE - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'KEY_LOG 2 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 1 ', 'MESSAGE_SENT 1 - KEY_LOG 1 ', 'KEY_LOG 3 - KEY_LOG 1 ', 'MESSAGE_SENT 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 1 ',  'INCALLUI_NOTI_TRUE 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_RESUMED 1 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_TRUE 2 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_FALSE - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'KEY_LOG 2 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING ', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_INCOMING', 'MESSAGE_SENT 1 - CALL_LOG_INCOMING', 'KEY_LOG 3 - CALL_LOG_INCOMING', 'MESSAGE_SENT 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING',  'MAP_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1',  'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'KEY_LOG 2 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 1 - INCALLUI_NOTI_FALSE', 'KEY_LOG 3 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 2', 'MESSAGE_SENT 1 - KEY_LOG 2', 'KEY_LOG 3 - KEY_LOG 2', 'MESSAGE_SENT 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 2', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 3', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 3', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 4', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 4', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - MESSAGE_SENT 1', 'MESSAGE_SENT 2 - MESSAGE_SENT 1', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 1', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 1', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 1',  'MESSAGE_SENT 2 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 3', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 3', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 3', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'KEY_LOG 1 - MESSAGE_INBOX', 'CALL_LOG_INCOMING - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 2 - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'KEY_LOG 2 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'MESSAGE_SENT 1 - MESSAGE_INBOX', 'KEY_LOG 3 - MESSAGE_INBOX', 'MESSAGE_SENT 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'KEY_LOG 1 - SMS_NOTI_TRUE', 'CALL_LOG_INCOMING - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 2 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'KEY_LOG 2 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'MESSAGE_SENT 1 - SMS_NOTI_TRUE', 'KEY_LOG 3 - SMS_NOTI_TRUE', 'MESSAGE_SENT 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ',  'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_PAUSED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 2 - KEY_LOG 1 ', 'INCALLUI_NOTI_FALSE - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'KEY_LOG 2 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 1 ', 'MESSAGE_SENT 1 - KEY_LOG 1 ', 'KEY_LOG 3 - KEY_LOG 1 ', 'MESSAGE_SENT 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 1 ',  'INCALLUI_NOTI_TRUE 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_RESUMED 1 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_TRUE 2 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_FALSE - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'KEY_LOG 2 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING ', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_INCOMING', 'MESSAGE_SENT 1 - CALL_LOG_INCOMING', 'KEY_LOG 3 - CALL_LOG_INCOMING', 'MESSAGE_SENT 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING',  'MAP_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1',  'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'KEY_LOG 2 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 1 - INCALLUI_NOTI_FALSE', 'KEY_LOG 3 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 2', 'MESSAGE_SENT 1 - KEY_LOG 2', 'KEY_LOG 3 - KEY_LOG 2', 'MESSAGE_SENT 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 2', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 3', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 3', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 4', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 4', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - MESSAGE_SENT 1', 'MESSAGE_SENT 2 - MESSAGE_SENT 1', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 1', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 1', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 1',  'MESSAGE_SENT 2 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 3', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 3', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 3', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'KEY_LOG 1 - MESSAGE_INBOX', 'CALL_LOG_INCOMING - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 2 - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'KEY_LOG 2 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'MESSAGE_SENT 1 - MESSAGE_INBOX', 'KEY_LOG 3 - MESSAGE_INBOX', 'MESSAGE_SENT 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'KEY_LOG 1 - SMS_NOTI_TRUE', 'CALL_LOG_INCOMING - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 2 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'KEY_LOG 2 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'MESSAGE_SENT 1 - SMS_NOTI_TRUE', 'KEY_LOG 3 - SMS_NOTI_TRUE', 'MESSAGE_SENT 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ',  'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_PAUSED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 2 - KEY_LOG 1 ', 'INCALLUI_NOTI_FALSE - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'KEY_LOG 2 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 1 ', 'MESSAGE_SENT 1 - KEY_LOG 1 ', 'KEY_LOG 3 - KEY_LOG 1 ', 'MESSAGE_SENT 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 1 ',  'INCALLUI_NOTI_TRUE 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_RESUMED 1 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_TRUE 2 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_FALSE - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'KEY_LOG 2 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING ', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_INCOMING', 'MESSAGE_SENT 1 - CALL_LOG_INCOMING', 'KEY_LOG 3 - CALL_LOG_INCOMING', 'MESSAGE_SENT 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING',  'MAP_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1',  'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'KEY_LOG 2 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 1 - INCALLUI_NOTI_FALSE', 'KEY_LOG 3 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 2', 'MESSAGE_SENT 1 - KEY_LOG 2', 'KEY_LOG 3 - KEY_LOG 2', 'MESSAGE_SENT 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 2', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 3', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 3', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 4', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 4', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - MESSAGE_SENT 1', 'MESSAGE_SENT 2 - MESSAGE_SENT 1', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 1', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 1', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 1',  'MESSAGE_SENT 2 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 3', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 3', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 3', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'KEY_LOG 1 - MESSAGE_INBOX', 'CALL_LOG_INCOMING - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 2 - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'KEY_LOG 2 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'MESSAGE_SENT 1 - MESSAGE_INBOX', 'KEY_LOG 3 - MESSAGE_INBOX', 'MESSAGE_SENT 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'KEY_LOG 1 - SMS_NOTI_TRUE', 'CALL_LOG_INCOMING - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 2 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'KEY_LOG 2 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'MESSAGE_SENT 1 - SMS_NOTI_TRUE', 'KEY_LOG 3 - SMS_NOTI_TRUE', 'MESSAGE_SENT 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ',  'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_PAUSED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 2 - KEY_LOG 1 ', 'INCALLUI_NOTI_FALSE - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'KEY_LOG 2 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 1 ', 'MESSAGE_SENT 1 - KEY_LOG 1 ', 'KEY_LOG 3 - KEY_LOG 1 ', 'MESSAGE_SENT 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 1 ',  'INCALLUI_NOTI_TRUE 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_RESUMED 1 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_TRUE 2 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_FALSE - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'KEY_LOG 2 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING ', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_INCOMING', 'MESSAGE_SENT 1 - CALL_LOG_INCOMING', 'KEY_LOG 3 - CALL_LOG_INCOMING', 'MESSAGE_SENT 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING',  'MAP_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1',  'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'KEY_LOG 2 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 1 - INCALLUI_NOTI_FALSE', 'KEY_LOG 3 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 2', 'MESSAGE_SENT 1 - KEY_LOG 2', 'KEY_LOG 3 - KEY_LOG 2', 'MESSAGE_SENT 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 2', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 3', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 3', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 4', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 4', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - MESSAGE_SENT 1', 'MESSAGE_SENT 2 - MESSAGE_SENT 1', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 1', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 1', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 1',  'MESSAGE_SENT 2 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 3', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 3', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 3', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'KEY_LOG 1 - MESSAGE_INBOX', 'CALL_LOG_INCOMING - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 2 - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'KEY_LOG 2 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'MESSAGE_SENT 1 - MESSAGE_INBOX', 'KEY_LOG 3 - MESSAGE_INBOX', 'MESSAGE_SENT 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'KEY_LOG 1 - SMS_NOTI_TRUE', 'CALL_LOG_INCOMING - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 2 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'KEY_LOG 2 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'MESSAGE_SENT 1 - SMS_NOTI_TRUE', 'KEY_LOG 3 - SMS_NOTI_TRUE', 'MESSAGE_SENT 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ',  'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_PAUSED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 2 - KEY_LOG 1 ', 'INCALLUI_NOTI_FALSE - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'KEY_LOG 2 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 1 ', 'MESSAGE_SENT 1 - KEY_LOG 1 ', 'KEY_LOG 3 - KEY_LOG 1 ', 'MESSAGE_SENT 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 1 ',  'INCALLUI_NOTI_TRUE 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_RESUMED 1 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_TRUE 2 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_FALSE - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'KEY_LOG 2 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING ', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_INCOMING', 'MESSAGE_SENT 1 - CALL_LOG_INCOMING', 'KEY_LOG 3 - CALL_LOG_INCOMING', 'MESSAGE_SENT 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING',  'MAP_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1',  'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'KEY_LOG 2 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 1 - INCALLUI_NOTI_FALSE', 'KEY_LOG 3 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 2', 'MESSAGE_SENT 1 - KEY_LOG 2', 'KEY_LOG 3 - KEY_LOG 2', 'MESSAGE_SENT 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 2', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 3', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 3', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 4', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 4', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - MESSAGE_SENT 1', 'MESSAGE_SENT 2 - MESSAGE_SENT 1', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 1', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 1', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 1',  'MESSAGE_SENT 2 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 3', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 3', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 3', 'SMS_NOTI_TRUE - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'KEY_LOG 1 - MESSAGE_INBOX', 'CALL_LOG_INCOMING - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_RESUMED 1 - MESSAGE_INBOX', 'INCALLUI_NOTI_TRUE 2 - MESSAGE_INBOX', 'INCALLUI_NOTI_FALSE - MESSAGE_INBOX', 'INCALLUI_ACTIVITY_PAUSED 1 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'KEY_LOG 2 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 4 - MESSAGE_INBOX', 'MESSAGE_SENT 1 - MESSAGE_INBOX', 'KEY_LOG 3 - MESSAGE_INBOX', 'MESSAGE_SENT 2 - MESSAGE_INBOX', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_INBOX', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_INBOX', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_INBOX', 'SMS_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'KEY_LOG 1 - SMS_NOTI_TRUE', 'CALL_LOG_INCOMING - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_TRUE 2 - SMS_NOTI_TRUE', 'INCALLUI_NOTI_FALSE - SMS_NOTI_TRUE', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'KEY_LOG 2 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_RESUMED 4 - SMS_NOTI_TRUE', 'MESSAGE_SENT 1 - SMS_NOTI_TRUE', 'KEY_LOG 3 - SMS_NOTI_TRUE', 'MESSAGE_SENT 2 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 4 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_RESUMED 3 - SMS_NOTI_TRUE', 'MAP_ACTIVITY_PAUSED 3 - SMS_NOTI_TRUE', 'SMS_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 1 ',  'MAP_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - SMS_ACTIVITY_PAUSED 1 ', 'CALL_LOG_INCOMING - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_TRUE 2 - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_NOTI_FALSE - SMS_ACTIVITY_PAUSED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 2 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 1 ', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 1 ', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 1 ', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 1 ', 'KEY_LOG 1 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_RESUMED 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 1 ', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 1 ', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 1 ', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 1 ', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 1 ', 'CALL_LOG_INCOMING - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_RESUMED 1 - KEY_LOG 1 ', 'INCALLUI_NOTI_TRUE 2 - KEY_LOG 1 ', 'INCALLUI_NOTI_FALSE - KEY_LOG 1 ', 'INCALLUI_ACTIVITY_PAUSED 1 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'KEY_LOG 2 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 1 ', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 1 ', 'MESSAGE_SENT 1 - KEY_LOG 1 ', 'KEY_LOG 3 - KEY_LOG 1 ', 'MESSAGE_SENT 2 - KEY_LOG 1 ', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 1 ', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 1 ', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 1 ',  'INCALLUI_NOTI_TRUE 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_RESUMED 1 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_TRUE 2 - CALL_LOG_INCOMING', 'INCALLUI_NOTI_FALSE - CALL_LOG_INCOMING', 'INCALLUI_ACTIVITY_PAUSED 1 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'KEY_LOG 2 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 2 - CALL_LOG_INCOMING ', 'SMS_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_RESUMED 4 - CALL_LOG_INCOMING', 'MESSAGE_SENT 1 - CALL_LOG_INCOMING', 'KEY_LOG 3 - CALL_LOG_INCOMING', 'MESSAGE_SENT 2 - CALL_LOG_INCOMING', 'SMS_ACTIVITY_PAUSED 4 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_RESUMED 3 - CALL_LOG_INCOMING', 'MAP_ACTIVITY_PAUSED 3 - CALL_LOG_INCOMING',  'MAP_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 1', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 1', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 1', 'INCALLUI_ACTIVITY_RESUMED 1 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_FALSE - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 1', 'INCALLUI_NOTI_TRUE 2 - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_NOTI_FALSE - INCALLUI_ACTIVITY_RESUMED 1', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_RESUMED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_RESUMED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_RESUMED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_RESUMED 1',  'INCALLUI_NOTI_FALSE - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 2 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 1 - INCALLUI_NOTI_TRUE 2', 'KEY_LOG 3 - INCALLUI_NOTI_TRUE 2', 'MESSAGE_SENT 2 - INCALLUI_NOTI_TRUE 2', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_TRUE 2', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_TRUE 2', 'INCALLUI_ACTIVITY_PAUSED 1 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'KEY_LOG 2 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 1 - INCALLUI_NOTI_FALSE', 'KEY_LOG 3 - INCALLUI_NOTI_FALSE', 'MESSAGE_SENT 2 - INCALLUI_NOTI_FALSE', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_NOTI_FALSE', 'MAP_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_RESUMED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 1 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MESSAGE_SENT 2 - INCALLUI_ACTIVITY_PAUSED 1', 'SMS_ACTIVITY_PAUSED 4 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_RESUMED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'MAP_ACTIVITY_PAUSED 3 - INCALLUI_ACTIVITY_PAUSED 1', 'KEY_LOG 2 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - MAP_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 2 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 4 - KEY_LOG 2', 'MESSAGE_SENT 1 - KEY_LOG 2', 'KEY_LOG 3 - KEY_LOG 2', 'MESSAGE_SENT 2 - KEY_LOG 2', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 2', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 2', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 2', 'SMS_ACTIVITY_RESUMED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - MAP_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - MAP_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - MAP_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 2', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 2', 'SMS_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 2', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 2', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 2', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 2', 'SMS_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 3', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 3', 'SMS_ACTIVITY_RESUMED 4 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_PAUSED 3', 'KEY_LOG 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 2 - SMS_ACTIVITY_PAUSED 3', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 3', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 3', 'MESSAGE_SENT 1 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - SMS_ACTIVITY_RESUMED 4', 'MESSAGE_SENT 2 - SMS_ACTIVITY_RESUMED 4', 'SMS_ACTIVITY_PAUSED 4 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_RESUMED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_RESUMED 4', 'KEY_LOG 3 - MESSAGE_SENT 1', 'MESSAGE_SENT 2 - MESSAGE_SENT 1', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 1', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 1', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 1',  'MESSAGE_SENT 2 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - KEY_LOG 3', 'MAP_ACTIVITY_RESUMED 3 - KEY_LOG 3', 'MAP_ACTIVITY_PAUSED 3 - KEY_LOG 3', 'SMS_ACTIVITY_PAUSED 4 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_PAUSED 3 - MESSAGE_SENT 2', 'MAP_ACTIVITY_RESUMED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - SMS_ACTIVITY_PAUSED 4', 'MAP_ACTIVITY_PAUSED 3 - MAP_ACTIVITY_RESUMED 3'
])

# %% [markdown]
# # Writing on the Sheet

# %%
with pd.ExcelWriter('/content/drive/My Drive/Lab/output.xlsx') as writer:  
    phone_register.to_excel(writer, sheet_name='phone_register')
    phone_receive.to_excel(writer, sheet_name='phone_receive')
    sms_reply.to_excel(writer, sheet_name='sms_reply')
    camera.to_excel(writer, sheet_name='camera')
    transfer.to_excel(writer, sheet_name='transfer')
    weather_searching.to_excel(writer, sheet_name='weather_searching')
    weather_switching.to_excel(writer, sheet_name='weather_switching')
    location_searching.to_excel(writer, sheet_name='location_searching')
    location_switching.to_excel(writer, sheet_name='location_switching')
    phone_register_E.to_excel(writer, sheet_name='phone_register_E')
    camera_E.to_excel(writer, sheet_name='camera_E')
